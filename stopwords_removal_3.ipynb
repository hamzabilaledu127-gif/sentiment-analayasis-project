# %%
import nltk
import re
import pandas as pd

# %%
data = pd.read_excel('error_dataset12.xlsx')

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 1746        1746          1746
# 1747        1747          1747
# 1748        1748          1748
# 1749        1749          1749
# 1750        1750          1750
#
#                                                Comments   M_Class
# 0     wonderful የተግባር ሆናቿል የwifi መቆራረጧንና ፍጥነት መቀነሷን ...  positive
# 1            telebirr ስከፍት የተሰጠኝን bonus እንዴት መጠቀም እችላለው  positive
# 2     ከባንክ ወደቴሌ ገንዘብ ስታስተላልፍ ቦነስ አለው ደስ ይላል አይደል በነገ...  positive
# 3            internet speed አስተካክሉ በጣም አይፈጥንም የብዙዎች ጥያቄ  positive
# 4     በሲዳማ ክልል ከሀዋሳ ዉጭ በቱም ወረዳ የሞባይል data connection...  negative
# ...                                                 ...       ...
# 1746                                          well done  positive
# ...

# %%
#stopword list uploading
stopwords = pd.read_excel('stopwords.xlsx', header=None)
stopwords = stopwords[0].to_list()

#applying stopword removal on dataset
data['Comments'] =data['Comments'].apply(lambda x: ' '.join([word for word in x.split() 
                                                             if word not in (stopwords)]))

# %%
stopwords = stopwords[0].to_list()

# %%
data['Comments'] = data['Comments'].astype('str')

# %%
data['Comments'] =data['Comments'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 1746        1746          1746
# 1747        1747          1747
# 1748        1748          1748
# 1749        1749          1749
# 1750        1750          1750
#
#                                                Comments   M_Class
# 0     wonderful የተግባር ሆናቿል የwifi መቆራረጧንና ፍጥነት መቀነሷን ...  positive
# 1            telebirr ስከፍት የተሰጠኝን bonus እንዴት መጠቀም እችላለው  positive
# 2     ከባንክ ወደቴሌ ገንዘብ ስታስተላልፍ ቦነስ አለው ደስ ይላል አይደል በነገ...  positive
# 3            internet speed አስተካክሉ በጣም አይፈጥንም የብዙዎች ጥያቄ  positive
# 4     በሲዳማ ክልል ከሀዋሳ ዉጭ በቱም ወረዳ የሞባይል data connection...  negative
# ...                                                 ...       ...
# 1746                                          well done  positive
# ...

# %%
writer = pd.ExcelWriter('error_dataset123.xlsx', engine='xlsxwriter')
data.to_excel(writer, sheet_name='data')
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 writer = pd.ExcelWriter('error_dataset123.xlsx', engine='xlsxwriter')
#       2 data.to_excel(writer, sheet_name='data')
#       3 writer.save()
#
# NameError: name 'pd' is not defined
