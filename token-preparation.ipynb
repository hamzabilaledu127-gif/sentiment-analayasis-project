# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# Download necessary NLTK resources
nltk.download('punkt')

# Load your Excel file
file_path = 'all_facebook_and_twitter_dataset.xlsx'

# Try loading the file with different engines based on extension
try:
    if file_path.endswith('.xlsx'):
        df = pd.read_excel(file_path, engine='openpyxl')
    elif file_path.endswith('.xls'):
        df = pd.read_excel(file_path, engine='xlrd')
    else:
        raise ValueError("File format not supported. Please provide a .xls or .xlsx file.")
except Exception as e:
    print(f"Error loading the Excel file: {e}")
    raise

# Function to tokenize comments
def tokenize_comment(comment):
    return word_tokenize(comment)

# Function to generate n-grams
def generate_ngrams(tokens, n):
    return list(ngrams(tokens, n))

# Apply tokenization and n-gram generation
df['Tokens'] = df['Comments'].apply(tokenize_comment)

# Choose the value of n for n-grams
n = 2  # For example, 2 for bigrams, 3 for trigrams, etc.
df['N-Grams'] = df['Tokens'].apply(lambda tokens: generate_ngrams(tokens, n))

# Print tokens and n-grams for each comment
for index, row in df.iterrows():
    print(f"Comment: {row['Comments']}")
    print(f"Tokens: {row['Tokens']}")
    print(f"{n}-Grams: {row['N-Grams']}")
    print("\n")

# If you need to save the tokens and n-grams back to the Excel file
output_file_path = 'all_facebook_and_twitter_dataset_with_ngrams.xlsx'
df.to_excel(output_file_path, index=False, engine='openpyxl')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Comment: እባካችሁ እለታዊ ፖኬጅ ላይም ማሻሻያ አድርጉ ለእኛ ለድሆቹም አስቡ እንጂ
# Tokens: ['እባካችሁ', 'እለታዊ', 'ፖኬጅ', 'ላይም', 'ማሻሻያ', 'አድርጉ', 'ለእኛ', 'ለድሆቹም', 'አስቡ', 'እንጂ']
# 2-Grams: [('እባካችሁ', 'እለታዊ'), ('እለታዊ', 'ፖኬጅ'), ('ፖኬጅ', 'ላይም'), ('ላይም', 'ማሻሻያ'), ('ማሻሻያ', 'አድርጉ'), ('አድርጉ', 'ለእኛ'), ('ለእኛ', 'ለድሆቹም'), ('ለድሆቹም', 'አስቡ'), ('አስቡ', 'እንጂ')]
#
#
# Comment: መቼነው ቅናሹ የሚጀምረው wifi የመኖሪያባለ mg ባለ mg የነበረው ስንት ሚቀንሰውስ
# Tokens: ['መቼነው', 'ቅናሹ', 'የሚጀምረው', 'wifi', 'የመኖሪያባለ', 'mg', 'ባለ', 'mg', 'የነበረው', 'ስንት', 'ሚቀንሰውስ']
# 2-Grams: [('መቼነው', 'ቅናሹ'), ('ቅናሹ', 'የሚጀምረው'), ('የሚጀምረው', 'wifi'), ('wifi', 'የመኖሪያባለ'), ('የመኖሪያባለ', 'mg'), ('mg', 'ባለ'), ('ባለ', 'mg'), ('mg', 'የነበረው'), ('የነበረው', 'ስንት'), ('ስንት', 'ሚቀንሰውስ')]
#
#
# Comment: የቴሌን የተወሰነ ለግሉ ዘርፍ ይሸጣል የተባለው የት ደረሰ ሀገሪቱ ተፎካካሪ የሆነ ሌላ አማራጭ ኔትወርክ ከሌላ መቼም የኢትዮጵያ ቴሌኮም ለደንበኛው ትኩረት የታሪፍ ማሻሻያ አያደርግም
# Tokens: ['የቴሌን', 'የተወሰነ', 'ለግሉ', 'ዘርፍ', 'ይሸጣል', 'የተባለው', 'የት', 'ደረሰ', 'ሀገሪቱ', 'ተፎካካሪ', 'የሆነ', 'ሌላ', 'አማራጭ', 'ኔትወርክ', 'ከሌላ', 'መቼም', 'የኢትዮጵያ', 'ቴሌኮም', 'ለደንበኛው', 'ትኩረት', 'የታሪፍ', 'ማሻሻያ', 'አያደርግም']
# 2-Grams: [('የቴሌን', 'የተወሰነ'), ('የተወሰነ', 'ለግሉ'), ('ለግሉ', 'ዘርፍ'), ('ዘርፍ', 'ይሸጣል'), ('ይሸጣል', 'የተባለው'), ('የተባለው', 'የት'), ('የት', 'ደረሰ'), ('ደረሰ', 'ሀገሪቱ'), ('ሀገሪቱ', 'ተፎካካሪ'), ('ተፎካካሪ', 'የሆነ'), ('የሆነ', 'ሌላ'), ('ሌላ', 'አማራጭ'), ('አማራጭ', 'ኔትወርክ'), ('ኔትወርክ', 'ከሌላ'), ('ከሌላ', 'መቼም'), ('መቼም', 'የኢትዮጵያ'), ('የኢትዮጵያ', 'ቴሌኮም'), ('ቴሌኮም', 'ለደንበኛው'), ('ለደንበኛው', 'ትኩረት'), ('ትኩረት', 'የታሪፍ'), ('የታሪፍ', 'ማሻሻያ'), ('ማሻሻያ', 'አያደርግም')]
#
#
# Comment: ምነው መልሱ ምላሽ ቆየ
# Tokens: ['ምነው', 'መልሱ', 'ምላሽ', 'ቆየ']
# 2-Grams: [('ምነው', 'መልሱ'), ('መልሱ', 'ምላሽ'), ('ምላሽ', 'ቆየ')]
#
#
# Comment: አዎ እናንቴ ሽልማት እያላችሁ በኛ ሙድ ያዙ
# Tokens: ['አዎ', 'እናንቴ', 'ሽልማት', 'እያላችሁ', 'በኛ', 'ሙድ', 'ያዙ']
# 2-Grams: [('አዎ', 'እናንቴ'), ('እናንቴ', 'ሽልማት'), ('ሽልማት', 'እያላችሁ'), ('እያላችሁ', 'በኛ'), ('በኛ', 'ሙድ'), ('ሙድ', 'ያዙ')]
#
#
# Comment: daily pakage መሆን አለበት በትንሹ
# Tokens: ['daily', 'pakage', 'መሆን', 'አለበት', 'በትንሹ']
# 2-Grams: [('daily', 'pakage'), ('pakage', 'መሆን'), ('መሆን', 'አለበት'), ('አለበት', 'በትንሹ')]
#
#
# Comment: የስልክ መስመሬ ሃክ ተደርጎ ካርድ ሞልቼ መጠቀም አልቻልኩም ጭራሽ ይበደሩበታል ይሁን በኔ ሲም ወንጀል ሰርተዉ ቃሊቲ እንዳይከቱኝ ስጋቴ እንዳላዘጋዉ ደግሞ ህዝቡ የምያዉቀኝ በሱ ሲም ካርድ ምን ይሻላል መላ በሉኝ ለግዜዉ ቤት ገዝቼ እየተጠቀምኩኝ ጨንቆኛል ምን ይሻላል
# Tokens: ['የስልክ', 'መስመሬ', 'ሃክ', 'ተደርጎ', 'ካርድ', 'ሞልቼ', 'መጠቀም', 'አልቻልኩም', 'ጭራሽ', 'ይበደሩበታል', 'ይሁን', 'በኔ', 'ሲም', 'ወንጀል', 'ሰርተዉ', 'ቃሊቲ', 'እንዳይከቱኝ', 'ስጋቴ', 'እንዳላዘጋዉ', 'ደግሞ', 'ህዝቡ', 'የምያዉቀኝ', 'በሱ', 'ሲም', 'ካርድ', 'ምን', 'ይሻላል', 'መላ', 'በሉኝ', 'ለግዜዉ', 'ቤት', 'ገዝቼ', 'እየተጠቀምኩኝ', 'ጨንቆኛል', 'ምን', 'ይሻላል']
# 2-Grams: [('የስልክ', 'መስመሬ'), ('መስመሬ', 'ሃክ'), ('ሃክ', 'ተደርጎ'), ('ተደርጎ', 'ካርድ'), ('ካርድ', 'ሞልቼ'), ('ሞልቼ', 'መጠቀም'), ('መጠቀም', 'አልቻልኩም'), ('አልቻልኩም', 'ጭራሽ'), ('ጭራሽ', 'ይበደሩበታል'), ('ይበደሩበታል', 'ይሁን'), ('ይሁን', 'በኔ'), ('በኔ', 'ሲም'), ('ሲም', 'ወንጀል'), ('ወንጀል', 'ሰርተዉ'), ('ሰርተዉ', 'ቃሊቲ'), ('ቃሊቲ', 'እንዳይከቱኝ'), ('እንዳይከቱኝ', 'ስጋቴ'), ('ስጋቴ', 'እንዳላዘጋዉ'), ('እንዳላዘጋዉ', 'ደግሞ'), ('ደግሞ', 'ህዝቡ'), ('ህዝቡ', 'የምያዉቀኝ'), ('የምያዉቀኝ', 'በሱ'), ('በሱ', 'ሲም'), ('ሲም', 'ካርድ'), ('ካርድ', 'ምን'), ('ምን', 'ይሻላል'), ('ይሻላል', 'መላ'), ('መላ', 'በሉኝ'), ('በሉኝ', 'ለግዜዉ'), ('ለግዜዉ', 'ቤት'), ('ቤት', 'ገዝቼ'), ('ገዝቼ', 'እየተጠቀምኩኝ'), ('እየተጠቀምኩኝ', 'ጨንቆኛል'), ('ጨንቆኛል', 'ምን'), ('ምን', 'ይሻላል')]
#
#
# Comment: የኢካፍ አገልግሎት የኢትዮ ቴሌኮም ስርጭትን ለማካተት መስፈርቶቹን እንፈልጋለን
# Tokens: ['የኢካፍ', 'አገልግሎት', 'የኢትዮ', 'ቴሌኮም', 'ስርጭትን', 'ለማካተት', 'መስፈርቶቹን', 'እንፈልጋለን']
# 2-Grams: [('የኢካፍ', 'አገልግሎት'), ('አገልግሎት', 'የኢትዮ'), ('የኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'ስርጭትን'), ('ስርጭትን', 'ለማካተት'), ('ለማካተት', 'መስፈርቶቹን'), ('መስፈርቶቹን', 'እንፈልጋለን')]
#
#
# Comment: አረ በፈጠራቹ አማራና አፋር ክልል የኢትዮ ቴሌኮም አካል አይደሉም እንዴ በጣም ያሳዝናልል እባካቹ ኢንተርኔቱን ልቀቁልን
# Tokens: ['አረ', 'በፈጠራቹ', 'አማራና', 'አፋር', 'ክልል', 'የኢትዮ', 'ቴሌኮም', 'አካል', 'አይደሉም', 'እንዴ', 'በጣም', 'ያሳዝናልል', 'እባካቹ', 'ኢንተርኔቱን', 'ልቀቁልን']
# 2-Grams: [('አረ', 'በፈጠራቹ'), ('በፈጠራቹ', 'አማራና'), ('አማራና', 'አፋር'), ('አፋር', 'ክልል'), ('ክልል', 'የኢትዮ'), ('የኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'አካል'), ('አካል', 'አይደሉም'), ('አይደሉም', 'እንዴ'), ('እንዴ', 'በጣም'), ('በጣም', 'ያሳዝናልል'), ('ያሳዝናልል', 'እባካቹ'), ('እባካቹ', 'ኢንተርኔቱን'), ('ኢንተርኔቱን', 'ልቀቁልን')]
#
#
# Comment: መልካም ስራ ነዉ
# Tokens: ['መልካም', 'ስራ', 'ነዉ']
# 2-Grams: [('መልካም', 'ስራ'), ('ስራ', 'ነዉ')]
#
#
# Comment: safaricom ገላግለን በናትህ
# Tokens: ['safaricom', 'ገላግለን', 'በናትህ']
# 2-Grams: [('safaricom', 'ገላግለን'), ('ገላግለን', 'በናትህ')]
#
#
# Comment: wifi በፊት ከምከፍለው ሂሳቡን ጨምራችሁ ያመጣቹብኝ
# Tokens: ['wifi', 'በፊት', 'ከምከፍለው', 'ሂሳቡን', 'ጨምራችሁ', 'ያመጣቹብኝ']
# 2-Grams: [('wifi', 'በፊት'), ('በፊት', 'ከምከፍለው'), ('ከምከፍለው', 'ሂሳቡን'), ('ሂሳቡን', 'ጨምራችሁ'), ('ጨምራችሁ', 'ያመጣቹብኝ')]
#
#
# Comment: ሽልማቱ ቀረ እንዴ
# Tokens: ['ሽልማቱ', 'ቀረ', 'እንዴ']
# 2-Grams: [('ሽልማቱ', 'ቀረ'), ('ቀረ', 'እንዴ')]
#
#
# Comment: ኮምፒውተር ገዝቼ በሰፈሬ የኢንተርኔት ኬብል የለንም ምን ማድረግ አለብኝ ቴሌዎች
# Tokens: ['ኮምፒውተር', 'ገዝቼ', 'በሰፈሬ', 'የኢንተርኔት', 'ኬብል', 'የለንም', 'ምን', 'ማድረግ', 'አለብኝ', 'ቴሌዎች']
# 2-Grams: [('ኮምፒውተር', 'ገዝቼ'), ('ገዝቼ', 'በሰፈሬ'), ('በሰፈሬ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ኬብል'), ('ኬብል', 'የለንም'), ('የለንም', 'ምን'), ('ምን', 'ማድረግ'), ('ማድረግ', 'አለብኝ'), ('አለብኝ', 'ቴሌዎች')]
#
#
# Comment: ለፈረንጆቹ በኣል የኢንተርኔት ቦነስ አትለቁልንም  እንዴ
# Tokens: ['ለፈረንጆቹ', 'በኣል', 'የኢንተርኔት', 'ቦነስ', 'አትለቁልንም', 'እንዴ']
# 2-Grams: [('ለፈረንጆቹ', 'በኣል'), ('በኣል', 'የኢንተርኔት'), ('የኢንተርኔት', 'ቦነስ'), ('ቦነስ', 'አትለቁልንም'), ('አትለቁልንም', 'እንዴ')]
#
#
# Comment: ethio telecom እጣው ከምን ደረሰ
# Tokens: ['ethio', 'telecom', 'እጣው', 'ከምን', 'ደረሰ']
# 2-Grams: [('ethio', 'telecom'), ('telecom', 'እጣው'), ('እጣው', 'ከምን'), ('ከምን', 'ደረሰ')]
#
#
# Comment: ያልገባኝ የለን ቴሌ ይሄንን ቴክስት ስትልኩ ከየትኛዎቹ የቴሌ ኩባንያዎቹ ጋር አወዳድረነው አስተያየት የምንሰጠው ባይሆን ቀጣይ የብልፅግና የስራ እቅድ ያለው በውጩም በሀገሩ በባለሀብት የሚከፈቱ የቴሌ ኩባንያዎች እውን ሆኖ ወደስራ ሲገባ ይሄንን ቴክስቶችን ብትልኩ ይሻላል ባይ
# Tokens: ['ያልገባኝ', 'የለን', 'ቴሌ', 'ይሄንን', 'ቴክስት', 'ስትልኩ', 'ከየትኛዎቹ', 'የቴሌ', 'ኩባንያዎቹ', 'ጋር', 'አወዳድረነው', 'አስተያየት', 'የምንሰጠው', 'ባይሆን', 'ቀጣይ', 'የብልፅግና', 'የስራ', 'እቅድ', 'ያለው', 'በውጩም', 'በሀገሩ', 'በባለሀብት', 'የሚከፈቱ', 'የቴሌ', 'ኩባንያዎች', 'እውን', 'ሆኖ', 'ወደስራ', 'ሲገባ', 'ይሄንን', 'ቴክስቶችን', 'ብትልኩ', 'ይሻላል', 'ባይ']
# 2-Grams: [('ያልገባኝ', 'የለን'), ('የለን', 'ቴሌ'), ('ቴሌ', 'ይሄንን'), ('ይሄንን', 'ቴክስት'), ('ቴክስት', 'ስትልኩ'), ('ስትልኩ', 'ከየትኛዎቹ'), ('ከየትኛዎቹ', 'የቴሌ'), ('የቴሌ', 'ኩባንያዎቹ'), ('ኩባንያዎቹ', 'ጋር'), ('ጋር', 'አወዳድረነው'), ('አወዳድረነው', 'አስተያየት'), ('አስተያየት', 'የምንሰጠው'), ('የምንሰጠው', 'ባይሆን'), ('ባይሆን', 'ቀጣይ'), ('ቀጣይ', 'የብልፅግና'), ('የብልፅግና', 'የስራ'), ('የስራ', 'እቅድ'), ('እቅድ', 'ያለው'), ('ያለው', 'በውጩም'), ('በውጩም', 'በሀገሩ'), ('በሀገሩ', 'በባለሀብት'), ('በባለሀብት', 'የሚከፈቱ'), ('የሚከፈቱ', 'የቴሌ'), ('የቴሌ', 'ኩባንያዎች'), ('ኩባንያዎች', 'እውን'), ('እውን', 'ሆኖ'), ('ሆኖ', 'ወደስራ'), ('ወደስራ', 'ሲገባ'), ('ሲገባ', 'ይሄንን'), ('ይሄንን', 'ቴክስቶችን'), ('ቴክስቶችን', 'ብትልኩ'), ('ብትልኩ', 'ይሻላል'), ('ይሻላል', 'ባይ')]
#
#
# Comment: cbe ጋር ያለው ችግር የምን ይሁን ቴሌብር ማዘዋወር አልተቻለም
# Tokens: ['cbe', 'ጋር', 'ያለው', 'ችግር', 'የምን', 'ይሁን', 'ቴሌብር', 'ማዘዋወር', 'አልተቻለም']
# 2-Grams: [('cbe', 'ጋር'), ('ጋር', 'ያለው'), ('ያለው', 'ችግር'), ('ችግር', 'የምን'), ('የምን', 'ይሁን'), ('ይሁን', 'ቴሌብር'), ('ቴሌብር', 'ማዘዋወር'), ('ማዘዋወር', 'አልተቻለም')]
#
#
# Comment: አረ wifi ቅናሹን አብራሩልን
# Tokens: ['አረ', 'wifi', 'ቅናሹን', 'አብራሩልን']
# 2-Grams: [('አረ', 'wifi'), ('wifi', 'ቅናሹን'), ('ቅናሹን', 'አብራሩልን')]
#
#
# Comment: መልካም ቀን ይሁንለዎት ስቀጥል ቴሌብር አልከፍትም አለኝ እኮ ምን ይሻላል ለኛም የእለታዊ ፓኬጅ ይቀንስልን
# Tokens: ['መልካም', 'ቀን', 'ይሁንለዎት', 'ስቀጥል', 'ቴሌብር', 'አልከፍትም', 'አለኝ', 'እኮ', 'ምን', 'ይሻላል', 'ለኛም', 'የእለታዊ', 'ፓኬጅ', 'ይቀንስልን']
# 2-Grams: [('መልካም', 'ቀን'), ('ቀን', 'ይሁንለዎት'), ('ይሁንለዎት', 'ስቀጥል'), ('ስቀጥል', 'ቴሌብር'), ('ቴሌብር', 'አልከፍትም'), ('አልከፍትም', 'አለኝ'), ('አለኝ', 'እኮ'), ('እኮ', 'ምን'), ('ምን', 'ይሻላል'), ('ይሻላል', 'ለኛም'), ('ለኛም', 'የእለታዊ'), ('የእለታዊ', 'ፓኬጅ'), ('ፓኬጅ', 'ይቀንስልን')]
#
#
# Comment: እነንታ በርቱሌና ከጉነቹህ ነን ስራቹህ የሚመሰገን
# Tokens: ['እነንታ', 'በርቱሌና', 'ከጉነቹህ', 'ነን', 'ስራቹህ', 'የሚመሰገን']
# 2-Grams: [('እነንታ', 'በርቱሌና'), ('በርቱሌና', 'ከጉነቹህ'), ('ከጉነቹህ', 'ነን'), ('ነን', 'ስራቹህ'), ('ስራቹህ', 'የሚመሰገን')]
#
#
# Comment: አረ wifi ቅናሹን አብራሩልንና ቀናችን ብሩህ ይሁን
# Tokens: ['አረ', 'wifi', 'ቅናሹን', 'አብራሩልንና', 'ቀናችን', 'ብሩህ', 'ይሁን']
# 2-Grams: [('አረ', 'wifi'), ('wifi', 'ቅናሹን'), ('ቅናሹን', 'አብራሩልንና'), ('አብራሩልንና', 'ቀናችን'), ('ቀናችን', 'ብሩህ'), ('ብሩህ', 'ይሁን')]
#
#
# Comment: ሽልማቱን በቶሎ ላኩልን
# Tokens: ['ሽልማቱን', 'በቶሎ', 'ላኩልን']
# 2-Grams: [('ሽልማቱን', 'በቶሎ'), ('በቶሎ', 'ላኩልን')]
#
#
# Comment: ቅናሸ መሆኑ የኑሮ ውድነትን ኢትዮጵያ ውስጥ ታባዛላችሁ
# Tokens: ['ቅናሸ', 'መሆኑ', 'የኑሮ', 'ውድነትን', 'ኢትዮጵያ', 'ውስጥ', 'ታባዛላችሁ']
# 2-Grams: [('ቅናሸ', 'መሆኑ'), ('መሆኑ', 'የኑሮ'), ('የኑሮ', 'ውድነትን'), ('ውድነትን', 'ኢትዮጵያ'), ('ኢትዮጵያ', 'ውስጥ'), ('ውስጥ', 'ታባዛላችሁ')]
#
#
# Comment: በጣም ጥሩ ስራ ደስ ይላል አዲሱን የዋይፋይ ዝርዝር ልቀቁልን
# Tokens: ['በጣም', 'ጥሩ', 'ስራ', 'ደስ', 'ይላል', 'አዲሱን', 'የዋይፋይ', 'ዝርዝር', 'ልቀቁልን']
# 2-Grams: [('በጣም', 'ጥሩ'), ('ጥሩ', 'ስራ'), ('ስራ', 'ደስ'), ('ደስ', 'ይላል'), ('ይላል', 'አዲሱን'), ('አዲሱን', 'የዋይፋይ'), ('የዋይፋይ', 'ዝርዝር'), ('ዝርዝር', 'ልቀቁልን')]
#
#
# Comment: ሽልማቱ ፉገራ ነበር ማለት
# Tokens: ['ሽልማቱ', 'ፉገራ', 'ነበር', 'ማለት']
# 2-Grams: [('ሽልማቱ', 'ፉገራ'), ('ፉገራ', 'ነበር'), ('ነበር', 'ማለት')]
#
#
# Comment: አያመጣም
# Tokens: ['አያመጣም']
# 2-Grams: []
#
#
# Comment: ያልተገደበ እለታዊ ጥቅል በቅርቡ እንደምታቀርቡ ተስፋ አለን
# Tokens: ['ያልተገደበ', 'እለታዊ', 'ጥቅል', 'በቅርቡ', 'እንደምታቀርቡ', 'ተስፋ', 'አለን']
# 2-Grams: [('ያልተገደበ', 'እለታዊ'), ('እለታዊ', 'ጥቅል'), ('ጥቅል', 'በቅርቡ'), ('በቅርቡ', 'እንደምታቀርቡ'), ('እንደምታቀርቡ', 'ተስፋ'), ('ተስፋ', 'አለን')]
#
#
# Comment: በርቱ ጥሩ ለውጥ እያሻሻላችሁ የኔትወርኩንም የኮኔክሽኑንም ነገር በደንብ ስሩበት
# Tokens: ['በርቱ', 'ጥሩ', 'ለውጥ', 'እያሻሻላችሁ', 'የኔትወርኩንም', 'የኮኔክሽኑንም', 'ነገር', 'በደንብ', 'ስሩበት']
# 2-Grams: [('በርቱ', 'ጥሩ'), ('ጥሩ', 'ለውጥ'), ('ለውጥ', 'እያሻሻላችሁ'), ('እያሻሻላችሁ', 'የኔትወርኩንም'), ('የኔትወርኩንም', 'የኮኔክሽኑንም'), ('የኮኔክሽኑንም', 'ነገር'), ('ነገር', 'በደንብ'), ('በደንብ', 'ስሩበት')]
#
#
# Comment: የኢንተርኔት ዋጋ ቀንሱልን በጣም ውድ የምታስከፍሉን
# Tokens: ['የኢንተርኔት', 'ዋጋ', 'ቀንሱልን', 'በጣም', 'ውድ', 'የምታስከፍሉን']
# 2-Grams: [('የኢንተርኔት', 'ዋጋ'), ('ዋጋ', 'ቀንሱልን'), ('ቀንሱልን', 'በጣም'), ('በጣም', 'ውድ'), ('ውድ', 'የምታስከፍሉን')]
#
#
# Comment: waiting safaricom service
# Tokens: ['waiting', 'safaricom', 'service']
# 2-Grams: [('waiting', 'safaricom'), ('safaricom', 'service')]
#
#
# Comment: ከገብ ጋር ማይመጣጠን መሆኑ አታውቅም እንዴ
# Tokens: ['ከገብ', 'ጋር', 'ማይመጣጠን', 'መሆኑ', 'አታውቅም', 'እንዴ']
# 2-Grams: [('ከገብ', 'ጋር'), ('ጋር', 'ማይመጣጠን'), ('ማይመጣጠን', 'መሆኑ'), ('መሆኑ', 'አታውቅም'), ('አታውቅም', 'እንዴ')]
#
#
# Comment: የእለታዊ ያልተገደበ ኢንተርኔት ጥቅል ብርም ቢሆን አስጀምሩልን
# Tokens: ['የእለታዊ', 'ያልተገደበ', 'ኢንተርኔት', 'ጥቅል', 'ብርም', 'ቢሆን', 'አስጀምሩልን']
# 2-Grams: [('የእለታዊ', 'ያልተገደበ'), ('ያልተገደበ', 'ኢንተርኔት'), ('ኢንተርኔት', 'ጥቅል'), ('ጥቅል', 'ብርም'), ('ብርም', 'ቢሆን'), ('ቢሆን', 'አስጀምሩልን')]
#
#
# Comment: ከጊዜው ጋር አብሮ የሚሄድ የተገልጋዮችን ፍላጎት እንዲሁም እርካታን በሚያሳድግ መልኩ በየጊዜው ስለምታቀርቡት ፓኬጅና ማሻሻያ እጅግ እናመሰግናለን በርቱልን
# Tokens: ['ከጊዜው', 'ጋር', 'አብሮ', 'የሚሄድ', 'የተገልጋዮችን', 'ፍላጎት', 'እንዲሁም', 'እርካታን', 'በሚያሳድግ', 'መልኩ', 'በየጊዜው', 'ስለምታቀርቡት', 'ፓኬጅና', 'ማሻሻያ', 'እጅግ', 'እናመሰግናለን', 'በርቱልን']
# 2-Grams: [('ከጊዜው', 'ጋር'), ('ጋር', 'አብሮ'), ('አብሮ', 'የሚሄድ'), ('የሚሄድ', 'የተገልጋዮችን'), ('የተገልጋዮችን', 'ፍላጎት'), ('ፍላጎት', 'እንዲሁም'), ('እንዲሁም', 'እርካታን'), ('እርካታን', 'በሚያሳድግ'), ('በሚያሳድግ', 'መልኩ'), ('መልኩ', 'በየጊዜው'), ('በየጊዜው', 'ስለምታቀርቡት'), ('ስለምታቀርቡት', 'ፓኬጅና'), ('ፓኬጅና', 'ማሻሻያ'), ('ማሻሻያ', 'እጅግ'), ('እጅግ', 'እናመሰግናለን'), ('እናመሰግናለን', 'በርቱልን')]
#
#
# Comment: በነገራችን ሳፍሪኮም መቸ ስራ የሚጀምረው የሰርቪስ አሰጣጡ እርጎ አሉ ፍሪየ እንዳትቀየሚኝ ለስራሽና ለለውጥ ላለሽ አክበሮት ምስጋናዬ ከፍ ያለ
# Tokens: ['በነገራችን', 'ሳፍሪኮም', 'መቸ', 'ስራ', 'የሚጀምረው', 'የሰርቪስ', 'አሰጣጡ', 'እርጎ', 'አሉ', 'ፍሪየ', 'እንዳትቀየሚኝ', 'ለስራሽና', 'ለለውጥ', 'ላለሽ', 'አክበሮት', 'ምስጋናዬ', 'ከፍ', 'ያለ']
# 2-Grams: [('በነገራችን', 'ሳፍሪኮም'), ('ሳፍሪኮም', 'መቸ'), ('መቸ', 'ስራ'), ('ስራ', 'የሚጀምረው'), ('የሚጀምረው', 'የሰርቪስ'), ('የሰርቪስ', 'አሰጣጡ'), ('አሰጣጡ', 'እርጎ'), ('እርጎ', 'አሉ'), ('አሉ', 'ፍሪየ'), ('ፍሪየ', 'እንዳትቀየሚኝ'), ('እንዳትቀየሚኝ', 'ለስራሽና'), ('ለስራሽና', 'ለለውጥ'), ('ለለውጥ', 'ላለሽ'), ('ላለሽ', 'አክበሮት'), ('አክበሮት', 'ምስጋናዬ'), ('ምስጋናዬ', 'ከፍ'), ('ከፍ', 'ያለ')]
#
#
# Comment: በጣም ጥሩ አሪፍ እናመሰግናለን
# Tokens: ['በጣም', 'ጥሩ', 'አሪፍ', 'እናመሰግናለን']
# 2-Grams: [('በጣም', 'ጥሩ'), ('ጥሩ', 'አሪፍ'), ('አሪፍ', 'እናመሰግናለን')]
#
#
# Comment: ቴሌብር መክፈት አልቻልኩም ምንድነው ችግሩ ከዛ register እላለው ከዛም አይሰራም
# Tokens: ['ቴሌብር', 'መክፈት', 'አልቻልኩም', 'ምንድነው', 'ችግሩ', 'ከዛ', 'register', 'እላለው', 'ከዛም', 'አይሰራም']
# 2-Grams: [('ቴሌብር', 'መክፈት'), ('መክፈት', 'አልቻልኩም'), ('አልቻልኩም', 'ምንድነው'), ('ምንድነው', 'ችግሩ'), ('ችግሩ', 'ከዛ'), ('ከዛ', 'register'), ('register', 'እላለው'), ('እላለው', 'ከዛም'), ('ከዛም', 'አይሰራም')]
#
#
# Comment: daily daily chengable way have growth technology appreciate person great chengable have question does data have done external cuntery
# Tokens: ['daily', 'daily', 'chengable', 'way', 'have', 'growth', 'technology', 'appreciate', 'person', 'great', 'chengable', 'have', 'question', 'does', 'data', 'have', 'done', 'external', 'cuntery']
# 2-Grams: [('daily', 'daily'), ('daily', 'chengable'), ('chengable', 'way'), ('way', 'have'), ('have', 'growth'), ('growth', 'technology'), ('technology', 'appreciate'), ('appreciate', 'person'), ('person', 'great'), ('great', 'chengable'), ('chengable', 'have'), ('have', 'question'), ('question', 'does'), ('does', 'data'), ('data', 'have'), ('have', 'done'), ('done', 'external'), ('external', 'cuntery')]
#
#
# Comment: ሌላ ምን ምርጫ አለን እናመሰግናለን
# Tokens: ['ሌላ', 'ምን', 'ምርጫ', 'አለን', 'እናመሰግናለን']
# 2-Grams: [('ሌላ', 'ምን'), ('ምን', 'ምርጫ'), ('ምርጫ', 'አለን'), ('አለን', 'እናመሰግናለን')]
#
#
# Comment: nice will more attractive start unlimited daily data service
# Tokens: ['nice', 'will', 'more', 'attractive', 'start', 'unlimited', 'daily', 'data', 'service']
# 2-Grams: [('nice', 'will'), ('will', 'more'), ('more', 'attractive'), ('attractive', 'start'), ('start', 'unlimited'), ('unlimited', 'daily'), ('daily', 'data'), ('data', 'service')]
#
#
# Comment: የኢንተርኔትም ቢታሰብበት ጥሩ
# Tokens: ['የኢንተርኔትም', 'ቢታሰብበት', 'ጥሩ']
# 2-Grams: [('የኢንተርኔትም', 'ቢታሰብበት'), ('ቢታሰብበት', 'ጥሩ')]
#
#
# Comment: ኢትዮ ቴሌኮም የምታደርጓቸው ማሻሻዎች ወደፊትም በደንበኝነታችን እንድንቀጥል የሚያደርግ ነውይህንን ማሻሻያ በኢንተርኔት ቢደረግ መልካም እንዲሁም የለሊት ኢንተርኔት ጥቅል ብታሻሽሉ ምክንያቱም wifi access የሌለን ተጠቃሚዎች ትልልቅ app ለማውረድ ውድ ስለሆነ
# Tokens: ['ኢትዮ', 'ቴሌኮም', 'የምታደርጓቸው', 'ማሻሻዎች', 'ወደፊትም', 'በደንበኝነታችን', 'እንድንቀጥል', 'የሚያደርግ', 'ነውይህንን', 'ማሻሻያ', 'በኢንተርኔት', 'ቢደረግ', 'መልካም', 'እንዲሁም', 'የለሊት', 'ኢንተርኔት', 'ጥቅል', 'ብታሻሽሉ', 'ምክንያቱም', 'wifi', 'access', 'የሌለን', 'ተጠቃሚዎች', 'ትልልቅ', 'app', 'ለማውረድ', 'ውድ', 'ስለሆነ']
# 2-Grams: [('ኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'የምታደርጓቸው'), ('የምታደርጓቸው', 'ማሻሻዎች'), ('ማሻሻዎች', 'ወደፊትም'), ('ወደፊትም', 'በደንበኝነታችን'), ('በደንበኝነታችን', 'እንድንቀጥል'), ('እንድንቀጥል', 'የሚያደርግ'), ('የሚያደርግ', 'ነውይህንን'), ('ነውይህንን', 'ማሻሻያ'), ('ማሻሻያ', 'በኢንተርኔት'), ('በኢንተርኔት', 'ቢደረግ'), ('ቢደረግ', 'መልካም'), ('መልካም', 'እንዲሁም'), ('እንዲሁም', 'የለሊት'), ('የለሊት', 'ኢንተርኔት'), ('ኢንተርኔት', 'ጥቅል'), ('ጥቅል', 'ብታሻሽሉ'), ('ብታሻሽሉ', 'ምክንያቱም'), ('ምክንያቱም', 'wifi'), ('wifi', 'access'), ('access', 'የሌለን'), ('የሌለን', 'ተጠቃሚዎች'), ('ተጠቃሚዎች', 'ትልልቅ'), ('ትልልቅ', 'app'), ('app', 'ለማውረድ'), ('ለማውረድ', 'ውድ'), ('ውድ', 'ስለሆነ')]
#
#
# Comment: what data
# Tokens: ['what', 'data']
# 2-Grams: [('what', 'data')]
#
#
# Comment: need data like
# Tokens: ['need', 'data', 'like']
# 2-Grams: [('need', 'data'), ('data', 'like')]
#
#
# Comment: እድሜ ለጠቅላያችን ይሁንና ገና ማሻሻያዎች ይቀራችኋል ከብዛት ለማግኘት ስሩ ተፎካካሪ ኩባንያ እየመጣባችሁ ስለሆነበተጨማሪ በይሙሉ አስር ፐርሰንት የምናገኘውን ኮሚሽን ለምን ቀነሳችሁት ያለ ምንም ወጪ የአየር ሰአት ግብይት ነበር ethiotelecom ሳንፈልግ ሳፍሪኮም safaricom የት እንድንል አታድርጉን
# Tokens: ['እድሜ', 'ለጠቅላያችን', 'ይሁንና', 'ገና', 'ማሻሻያዎች', 'ይቀራችኋል', 'ከብዛት', 'ለማግኘት', 'ስሩ', 'ተፎካካሪ', 'ኩባንያ', 'እየመጣባችሁ', 'ስለሆነበተጨማሪ', 'በይሙሉ', 'አስር', 'ፐርሰንት', 'የምናገኘውን', 'ኮሚሽን', 'ለምን', 'ቀነሳችሁት', 'ያለ', 'ምንም', 'ወጪ', 'የአየር', 'ሰአት', 'ግብይት', 'ነበር', 'ethiotelecom', 'ሳንፈልግ', 'ሳፍሪኮም', 'safaricom', 'የት', 'እንድንል', 'አታድርጉን']
# 2-Grams: [('እድሜ', 'ለጠቅላያችን'), ('ለጠቅላያችን', 'ይሁንና'), ('ይሁንና', 'ገና'), ('ገና', 'ማሻሻያዎች'), ('ማሻሻያዎች', 'ይቀራችኋል'), ('ይቀራችኋል', 'ከብዛት'), ('ከብዛት', 'ለማግኘት'), ('ለማግኘት', 'ስሩ'), ('ስሩ', 'ተፎካካሪ'), ('ተፎካካሪ', 'ኩባንያ'), ('ኩባንያ', 'እየመጣባችሁ'), ('እየመጣባችሁ', 'ስለሆነበተጨማሪ'), ('ስለሆነበተጨማሪ', 'በይሙሉ'), ('በይሙሉ', 'አስር'), ('አስር', 'ፐርሰንት'), ('ፐርሰንት', 'የምናገኘውን'), ('የምናገኘውን', 'ኮሚሽን'), ('ኮሚሽን', 'ለምን'), ('ለምን', 'ቀነሳችሁት'), ('ቀነሳችሁት', 'ያለ'), ('ያለ', 'ምንም'), ('ምንም', 'ወጪ'), ('ወጪ', 'የአየር'), ('የአየር', 'ሰአት'), ('ሰአት', 'ግብይት'), ('ግብይት', 'ነበር'), ('ነበር', 'ethiotelecom'), ('ethiotelecom', 'ሳንፈልግ'), ('ሳንፈልግ', 'ሳፍሪኮም'), ('ሳፍሪኮም', 'safaricom'), ('safaricom', 'የት'), ('የት', 'እንድንል'), ('እንድንል', 'አታድርጉን')]
#
#
# Comment: safaricom መቶልሻል ethio telecom ፍሪ safaricom ገብተናል እናንተስ users
# Tokens: ['safaricom', 'መቶልሻል', 'ethio', 'telecom', 'ፍሪ', 'safaricom', 'ገብተናል', 'እናንተስ', 'users']
# 2-Grams: [('safaricom', 'መቶልሻል'), ('መቶልሻል', 'ethio'), ('ethio', 'telecom'), ('telecom', 'ፍሪ'), ('ፍሪ', 'safaricom'), ('safaricom', 'ገብተናል'), ('ገብተናል', 'እናንተስ'), ('እናንተስ', 'users')]
#
#
# Comment: በናታቹ እለታዊ ያልተገደበ ኢንተርኔት አምጡና ሁላችንንም አስደስቱን
# Tokens: ['በናታቹ', 'እለታዊ', 'ያልተገደበ', 'ኢንተርኔት', 'አምጡና', 'ሁላችንንም', 'አስደስቱን']
# 2-Grams: [('በናታቹ', 'እለታዊ'), ('እለታዊ', 'ያልተገደበ'), ('ያልተገደበ', 'ኢንተርኔት'), ('ኢንተርኔት', 'አምጡና'), ('አምጡና', 'ሁላችንንም'), ('ሁላችንንም', 'አስደስቱን')]
#
#
# Comment: እለታዊ ያልተገደበ የኢንተርኔ ጥቅልስ የለም
# Tokens: ['እለታዊ', 'ያልተገደበ', 'የኢንተርኔ', 'ጥቅልስ', 'የለም']
# 2-Grams: [('እለታዊ', 'ያልተገደበ'), ('ያልተገደበ', 'የኢንተርኔ'), ('የኢንተርኔ', 'ጥቅልስ'), ('ጥቅልስ', 'የለም')]
#
#
# Comment: ቴሌዎችዬ አፈር ስሆንላችሁ ኢንተርኔትም ተመሳሳይ ጀምሩ
# Tokens: ['ቴሌዎችዬ', 'አፈር', 'ስሆንላችሁ', 'ኢንተርኔትም', 'ተመሳሳይ', 'ጀምሩ']
# 2-Grams: [('ቴሌዎችዬ', 'አፈር'), ('አፈር', 'ስሆንላችሁ'), ('ስሆንላችሁ', 'ኢንተርኔትም'), ('ኢንተርኔትም', 'ተመሳሳይ'), ('ተመሳሳይ', 'ጀምሩ')]
#
#
# Comment: ጨጓራ የሌለብኝን ሊጀማምረኝ እስካሁን ቴሌ በዘመነው ልክ አብሮ ያልሄደ የአገልግሎት መስጫ ፈትሹት ቶሎ ስልኩ ይነሳ
# Tokens: ['ጨጓራ', 'የሌለብኝን', 'ሊጀማምረኝ', 'እስካሁን', 'ቴሌ', 'በዘመነው', 'ልክ', 'አብሮ', 'ያልሄደ', 'የአገልግሎት', 'መስጫ', 'ፈትሹት', 'ቶሎ', 'ስልኩ', 'ይነሳ']
# 2-Grams: [('ጨጓራ', 'የሌለብኝን'), ('የሌለብኝን', 'ሊጀማምረኝ'), ('ሊጀማምረኝ', 'እስካሁን'), ('እስካሁን', 'ቴሌ'), ('ቴሌ', 'በዘመነው'), ('በዘመነው', 'ልክ'), ('ልክ', 'አብሮ'), ('አብሮ', 'ያልሄደ'), ('ያልሄደ', 'የአገልግሎት'), ('የአገልግሎት', 'መስጫ'), ('መስጫ', 'ፈትሹት'), ('ፈትሹት', 'ቶሎ'), ('ቶሎ', 'ስልኩ'), ('ስልኩ', 'ይነሳ')]
#
#
# Comment: እንተርነት ዳታ ታርፍ speed ስልክ ለምን ገዛን በምንለው ደረጃ አድርሶናል ትንሽ ማሻሽያ ብደረግ አመሰግናለሁ
# Tokens: ['እንተርነት', 'ዳታ', 'ታርፍ', 'speed', 'ስልክ', 'ለምን', 'ገዛን', 'በምንለው', 'ደረጃ', 'አድርሶናል', 'ትንሽ', 'ማሻሽያ', 'ብደረግ', 'አመሰግናለሁ']
# 2-Grams: [('እንተርነት', 'ዳታ'), ('ዳታ', 'ታርፍ'), ('ታርፍ', 'speed'), ('speed', 'ስልክ'), ('ስልክ', 'ለምን'), ('ለምን', 'ገዛን'), ('ገዛን', 'በምንለው'), ('በምንለው', 'ደረጃ'), ('ደረጃ', 'አድርሶናል'), ('አድርሶናል', 'ትንሽ'), ('ትንሽ', 'ማሻሽያ'), ('ማሻሽያ', 'ብደረግ'), ('ብደረግ', 'አመሰግናለሁ')]
#
#
# Comment: dear ethio telecom possible convert month package form another form example package have minutes telebirr question want convert voice vs verse possible please
# Tokens: ['dear', 'ethio', 'telecom', 'possible', 'convert', 'month', 'package', 'form', 'another', 'form', 'example', 'package', 'have', 'minutes', 'telebirr', 'question', 'want', 'convert', 'voice', 'vs', 'verse', 'possible', 'please']
# 2-Grams: [('dear', 'ethio'), ('ethio', 'telecom'), ('telecom', 'possible'), ('possible', 'convert'), ('convert', 'month'), ('month', 'package'), ('package', 'form'), ('form', 'another'), ('another', 'form'), ('form', 'example'), ('example', 'package'), ('package', 'have'), ('have', 'minutes'), ('minutes', 'telebirr'), ('telebirr', 'question'), ('question', 'want'), ('want', 'convert'), ('convert', 'voice'), ('voice', 'vs'), ('vs', 'verse'), ('verse', 'possible'), ('possible', 'please')]
#
#
# Comment: በጣም አሪፍ ስራ እየሰራቹ ያላችሁት በርቱ wifi እያሰባቹ ቆያቹብን
# Tokens: ['በጣም', 'አሪፍ', 'ስራ', 'እየሰራቹ', 'ያላችሁት', 'በርቱ', 'wifi', 'እያሰባቹ', 'ቆያቹብን']
# 2-Grams: [('በጣም', 'አሪፍ'), ('አሪፍ', 'ስራ'), ('ስራ', 'እየሰራቹ'), ('እየሰራቹ', 'ያላችሁት'), ('ያላችሁት', 'በርቱ'), ('በርቱ', 'wifi'), ('wifi', 'እያሰባቹ'), ('እያሰባቹ', 'ቆያቹብን')]
#
#
# Comment: ተሸላሚዎች ዝርዝር ውስጥ ስሜ አለ ሽልማቱ አልደረሰኝም ይሄ ምን የሚሉት ማጭበርበር አረ በመንግስት እምነት አታሳጡን
# Tokens: ['ተሸላሚዎች', 'ዝርዝር', 'ውስጥ', 'ስሜ', 'አለ', 'ሽልማቱ', 'አልደረሰኝም', 'ይሄ', 'ምን', 'የሚሉት', 'ማጭበርበር', 'አረ', 'በመንግስት', 'እምነት', 'አታሳጡን']
# 2-Grams: [('ተሸላሚዎች', 'ዝርዝር'), ('ዝርዝር', 'ውስጥ'), ('ውስጥ', 'ስሜ'), ('ስሜ', 'አለ'), ('አለ', 'ሽልማቱ'), ('ሽልማቱ', 'አልደረሰኝም'), ('አልደረሰኝም', 'ይሄ'), ('ይሄ', 'ምን'), ('ምን', 'የሚሉት'), ('የሚሉት', 'ማጭበርበር'), ('ማጭበርበር', 'አረ'), ('አረ', 'በመንግስት'), ('በመንግስት', 'እምነት'), ('እምነት', 'አታሳጡን')]
#
#
# Comment: የኢንተርኔት አድርጉልን
# Tokens: ['የኢንተርኔት', 'አድርጉልን']
# 2-Grams: [('የኢንተርኔት', 'አድርጉልን')]
#
#
# Comment: አሪፍ የኢንተርኔት ቢሆን
# Tokens: ['አሪፍ', 'የኢንተርኔት', 'ቢሆን']
# 2-Grams: [('አሪፍ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ቢሆን')]
#
#
# Comment: በቴሌብር ይሆናል ማለት ቀኑን ሙሉ ማለት
# Tokens: ['በቴሌብር', 'ይሆናል', 'ማለት', 'ቀኑን', 'ሙሉ', 'ማለት']
# 2-Grams: [('በቴሌብር', 'ይሆናል'), ('ይሆናል', 'ማለት'), ('ማለት', 'ቀኑን'), ('ቀኑን', 'ሙሉ'), ('ሙሉ', 'ማለት')]
#
#
# Comment: unlimited internet package must get discounted begin daily unlimited internet package
# Tokens: ['unlimited', 'internet', 'package', 'must', 'get', 'discounted', 'begin', 'daily', 'unlimited', 'internet', 'package']
# 2-Grams: [('unlimited', 'internet'), ('internet', 'package'), ('package', 'must'), ('must', 'get'), ('get', 'discounted'), ('discounted', 'begin'), ('begin', 'daily'), ('daily', 'unlimited'), ('unlimited', 'internet'), ('internet', 'package')]
#
#
# Comment: ለምንድነው ልጁ ሽልማት ውስጥ ስሙ ኖሮ ሽልማቱን የማትልኩለት ፍርዬ ይሄንን ስራቹን ታውቃለች ዋ
# Tokens: ['ለምንድነው', 'ልጁ', 'ሽልማት', 'ውስጥ', 'ስሙ', 'ኖሮ', 'ሽልማቱን', 'የማትልኩለት', 'ፍርዬ', 'ይሄንን', 'ስራቹን', 'ታውቃለች', 'ዋ']
# 2-Grams: [('ለምንድነው', 'ልጁ'), ('ልጁ', 'ሽልማት'), ('ሽልማት', 'ውስጥ'), ('ውስጥ', 'ስሙ'), ('ስሙ', 'ኖሮ'), ('ኖሮ', 'ሽልማቱን'), ('ሽልማቱን', 'የማትልኩለት'), ('የማትልኩለት', 'ፍርዬ'), ('ፍርዬ', 'ይሄንን'), ('ይሄንን', 'ስራቹን'), ('ስራቹን', 'ታውቃለች'), ('ታውቃለች', 'ዋ')]
#
#
# Comment: real warm appreciation keep going step ahead
# Tokens: ['real', 'warm', 'appreciation', 'keep', 'going', 'step', 'ahead']
# 2-Grams: [('real', 'warm'), ('warm', 'appreciation'), ('appreciation', 'keep'), ('keep', 'going'), ('going', 'step'), ('step', 'ahead')]
#
#
# Comment: ዳታ ልቀቁልን ለሀገሪቱ ስጋት ካልሆነ ማለቴ
# Tokens: ['ዳታ', 'ልቀቁልን', 'ለሀገሪቱ', 'ስጋት', 'ካልሆነ', 'ማለቴ']
# 2-Grams: [('ዳታ', 'ልቀቁልን'), ('ልቀቁልን', 'ለሀገሪቱ'), ('ለሀገሪቱ', 'ስጋት'), ('ስጋት', 'ካልሆነ'), ('ካልሆነ', 'ማለቴ')]
#
#
# Comment: አረ የዳታ የቸገረን እባካችሁ
# Tokens: ['አረ', 'የዳታ', 'የቸገረን', 'እባካችሁ']
# 2-Grams: [('አረ', 'የዳታ'), ('የዳታ', 'የቸገረን'), ('የቸገረን', 'እባካችሁ')]
#
#
# Comment: ያልተገደበ ኢንተርኔትም ብትጨምሩ በጣም ጥሩ
# Tokens: ['ያልተገደበ', 'ኢንተርኔትም', 'ብትጨምሩ', 'በጣም', 'ጥሩ']
# 2-Grams: [('ያልተገደበ', 'ኢንተርኔትም'), ('ኢንተርኔትም', 'ብትጨምሩ'), ('ብትጨምሩ', 'በጣም'), ('በጣም', 'ጥሩ')]
#
#
# Comment: በሉ በነካ እጃችሁ ኢንተርኔቷንም unlimited daily internet package ስሩላት
# Tokens: ['በሉ', 'በነካ', 'እጃችሁ', 'ኢንተርኔቷንም', 'unlimited', 'daily', 'internet', 'package', 'ስሩላት']
# 2-Grams: [('በሉ', 'በነካ'), ('በነካ', 'እጃችሁ'), ('እጃችሁ', 'ኢንተርኔቷንም'), ('ኢንተርኔቷንም', 'unlimited'), ('unlimited', 'daily'), ('daily', 'internet'), ('internet', 'package'), ('package', 'ስሩላት')]
#
#
# Comment: ጥሩ የብዙ ሰዎች ጥያቄ ፍላጎት መሰረት ያልተገደበ ኢንተርኔት ብትለቁልን ጥሩ የብዙ ሰዎች ጥያቄና ፍላጎትም በተረፈ ጥሩ ያላቹህ በየግዜው የምትለቁልን አዳዲስ ቅናሾች ይልመድባቹህ
# Tokens: ['ጥሩ', 'የብዙ', 'ሰዎች', 'ጥያቄ', 'ፍላጎት', 'መሰረት', 'ያልተገደበ', 'ኢንተርኔት', 'ብትለቁልን', 'ጥሩ', 'የብዙ', 'ሰዎች', 'ጥያቄና', 'ፍላጎትም', 'በተረፈ', 'ጥሩ', 'ያላቹህ', 'በየግዜው', 'የምትለቁልን', 'አዳዲስ', 'ቅናሾች', 'ይልመድባቹህ']
# 2-Grams: [('ጥሩ', 'የብዙ'), ('የብዙ', 'ሰዎች'), ('ሰዎች', 'ጥያቄ'), ('ጥያቄ', 'ፍላጎት'), ('ፍላጎት', 'መሰረት'), ('መሰረት', 'ያልተገደበ'), ('ያልተገደበ', 'ኢንተርኔት'), ('ኢንተርኔት', 'ብትለቁልን'), ('ብትለቁልን', 'ጥሩ'), ('ጥሩ', 'የብዙ'), ('የብዙ', 'ሰዎች'), ('ሰዎች', 'ጥያቄና'), ('ጥያቄና', 'ፍላጎትም'), ('ፍላጎትም', 'በተረፈ'), ('በተረፈ', 'ጥሩ'), ('ጥሩ', 'ያላቹህ'), ('ያላቹህ', 'በየግዜው'), ('በየግዜው', 'የምትለቁልን'), ('የምትለቁልን', 'አዳዲስ'), ('አዳዲስ', 'ቅናሾች'), ('ቅናሾች', 'ይልመድባቹህ')]
#
#
# Comment: wow good news what do think daily unlimited data
# Tokens: ['wow', 'good', 'news', 'what', 'do', 'think', 'daily', 'unlimited', 'data']
# 2-Grams: [('wow', 'good'), ('good', 'news'), ('news', 'what'), ('what', 'do'), ('do', 'think'), ('think', 'daily'), ('daily', 'unlimited'), ('unlimited', 'data')]
#
#
# Comment: በቀን ረጅም ለብዙ ጆሮ ስልክ ማቆየት ጉዳት እንዳለው ጤና ባለሙያዎች ያስረዳሉ እርስዎስ ethiotelecom ምን አሰበ
# Tokens: ['በቀን', 'ረጅም', 'ለብዙ', 'ጆሮ', 'ስልክ', 'ማቆየት', 'ጉዳት', 'እንዳለው', 'ጤና', 'ባለሙያዎች', 'ያስረዳሉ', 'እርስዎስ', 'ethiotelecom', 'ምን', 'አሰበ']
# 2-Grams: [('በቀን', 'ረጅም'), ('ረጅም', 'ለብዙ'), ('ለብዙ', 'ጆሮ'), ('ጆሮ', 'ስልክ'), ('ስልክ', 'ማቆየት'), ('ማቆየት', 'ጉዳት'), ('ጉዳት', 'እንዳለው'), ('እንዳለው', 'ጤና'), ('ጤና', 'ባለሙያዎች'), ('ባለሙያዎች', 'ያስረዳሉ'), ('ያስረዳሉ', 'እርስዎስ'), ('እርስዎስ', 'ethiotelecom'), ('ethiotelecom', 'ምን'), ('ምን', 'አሰበ')]
#
#
# Comment: how many fixed internet router
# Tokens: ['how', 'many', 'fixed', 'internet', 'router']
# 2-Grams: [('how', 'many'), ('many', 'fixed'), ('fixed', 'internet'), ('internet', 'router')]
#
#
# Comment: data ጥቅልንም ብጨምሩበት መልካም
# Tokens: ['data', 'ጥቅልንም', 'ብጨምሩበት', 'መልካም']
# 2-Grams: [('data', 'ጥቅልንም'), ('ጥቅልንም', 'ብጨምሩበት'), ('ብጨምሩበት', 'መልካም')]
#
#
# Comment: telebirr password እረስቼው ነበር ማስተካከል አይችልም እንዴ
# Tokens: ['telebirr', 'password', 'እረስቼው', 'ነበር', 'ማስተካከል', 'አይችልም', 'እንዴ']
# 2-Grams: [('telebirr', 'password'), ('password', 'እረስቼው'), ('እረስቼው', 'ነበር'), ('ነበር', 'ማስተካከል'), ('ማስተካከል', 'አይችልም'), ('አይችልም', 'እንዴ')]
#
#
# Comment: ለውጥን አለ ጃል
# Tokens: ['ለውጥን', 'አለ', 'ጃል']
# 2-Grams: [('ለውጥን', 'አለ'), ('አለ', 'ጃል')]
#
#
# Comment: ምነው ሸዋ ከተለወጡ አይቀር እንዲ
# Tokens: ['ምነው', 'ሸዋ', 'ከተለወጡ', 'አይቀር', 'እንዲ']
# 2-Grams: [('ምነው', 'ሸዋ'), ('ሸዋ', 'ከተለወጡ'), ('ከተለወጡ', 'አይቀር'), ('አይቀር', 'እንዲ')]
#
#
# Comment: ሳልኮምት ባልፍ ቴሌራሱ ይታዘበኛል አሪፍ ነገር የወር ያልተገደበ በተመጣጣኝ ዋጋ ብትጀምሩ ያለችው በዛ ትላለች
# Tokens: ['ሳልኮምት', 'ባልፍ', 'ቴሌራሱ', 'ይታዘበኛል', 'አሪፍ', 'ነገር', 'የወር', 'ያልተገደበ', 'በተመጣጣኝ', 'ዋጋ', 'ብትጀምሩ', 'ያለችው', 'በዛ', 'ትላለች']
# 2-Grams: [('ሳልኮምት', 'ባልፍ'), ('ባልፍ', 'ቴሌራሱ'), ('ቴሌራሱ', 'ይታዘበኛል'), ('ይታዘበኛል', 'አሪፍ'), ('አሪፍ', 'ነገር'), ('ነገር', 'የወር'), ('የወር', 'ያልተገደበ'), ('ያልተገደበ', 'በተመጣጣኝ'), ('በተመጣጣኝ', 'ዋጋ'), ('ዋጋ', 'ብትጀምሩ'), ('ብትጀምሩ', 'ያለችው'), ('ያለችው', 'በዛ'), ('በዛ', 'ትላለች')]
#
#
# Comment: need daily unlimited internet package
# Tokens: ['need', 'daily', 'unlimited', 'internet', 'package']
# 2-Grams: [('need', 'daily'), ('daily', 'unlimited'), ('unlimited', 'internet'), ('internet', 'package')]
#
#
# Comment: አረ shame ዘንድሮ የገና ጥቅል ከለከላችሁ
# Tokens: ['አረ', 'shame', 'ዘንድሮ', 'የገና', 'ጥቅል', 'ከለከላችሁ']
# 2-Grams: [('አረ', 'shame'), ('shame', 'ዘንድሮ'), ('ዘንድሮ', 'የገና'), ('የገና', 'ጥቅል'), ('ጥቅል', 'ከለከላችሁ')]
#
#
# Comment: region enternat data ልቀቁልን
# Tokens: ['region', 'enternat', 'data', 'ልቀቁልን']
# 2-Grams: [('region', 'enternat'), ('enternat', 'data'), ('data', 'ልቀቁልን')]
#
#
# Comment: wife የሌለን ምን ይዋጠን data ላኩልን
# Tokens: ['wife', 'የሌለን', 'ምን', 'ይዋጠን', 'data', 'ላኩልን']
# 2-Grams: [('wife', 'የሌለን'), ('የሌለን', 'ምን'), ('ምን', 'ይዋጠን'), ('ይዋጠን', 'data'), ('data', 'ላኩልን')]
#
#
# Comment: ምለው የይለፋ ካለ አስገቡት እያሉ አስችግርቺኝኮ
# Tokens: ['ምለው', 'የይለፋ', 'ካለ', 'አስገቡት', 'እያሉ', 'አስችግርቺኝኮ']
# 2-Grams: [('ምለው', 'የይለፋ'), ('የይለፋ', 'ካለ'), ('ካለ', 'አስገቡት'), ('አስገቡት', 'እያሉ'), ('እያሉ', 'አስችግርቺኝኮ')]
#
#
# Comment: እውነተኛ መንገድ ኢትዮቴሌኮም ደስታችንን እጥፍ ደርብ አድርጋችኋል እናመሰግናለን እንወዳችኋለን
# Tokens: ['እውነተኛ', 'መንገድ', 'ኢትዮቴሌኮም', 'ደስታችንን', 'እጥፍ', 'ደርብ', 'አድርጋችኋል', 'እናመሰግናለን', 'እንወዳችኋለን']
# 2-Grams: [('እውነተኛ', 'መንገድ'), ('መንገድ', 'ኢትዮቴሌኮም'), ('ኢትዮቴሌኮም', 'ደስታችንን'), ('ደስታችንን', 'እጥፍ'), ('እጥፍ', 'ደርብ'), ('ደርብ', 'አድርጋችኋል'), ('አድርጋችኋል', 'እናመሰግናለን'), ('እናመሰግናለን', 'እንወዳችኋለን')]
#
#
# Comment: ፍርዬ እድሜሽን ያርዝመው እንደው ምናለ ንግድ ባንክ ብዞሪ ጥሩ ነበር
# Tokens: ['ፍርዬ', 'እድሜሽን', 'ያርዝመው', 'እንደው', 'ምናለ', 'ንግድ', 'ባንክ', 'ብዞሪ', 'ጥሩ', 'ነበር']
# 2-Grams: [('ፍርዬ', 'እድሜሽን'), ('እድሜሽን', 'ያርዝመው'), ('ያርዝመው', 'እንደው'), ('እንደው', 'ምናለ'), ('ምናለ', 'ንግድ'), ('ንግድ', 'ባንክ'), ('ባንክ', 'ብዞሪ'), ('ብዞሪ', 'ጥሩ'), ('ጥሩ', 'ነበር')]
#
#
# Comment: ሰፋሪኮም ምናምን ኢቲዮ ቴሌኮም እናመሰግናለን ብዙ ለውጥ አለ ነገርግን ብዙ ካርድ ለሚጠቀሙ ደንበኞች ልዩ ሽልማት ብታዘጋጁ
# Tokens: ['ሰፋሪኮም', 'ምናምን', 'ኢቲዮ', 'ቴሌኮም', 'እናመሰግናለን', 'ብዙ', 'ለውጥ', 'አለ', 'ነገርግን', 'ብዙ', 'ካርድ', 'ለሚጠቀሙ', 'ደንበኞች', 'ልዩ', 'ሽልማት', 'ብታዘጋጁ']
# 2-Grams: [('ሰፋሪኮም', 'ምናምን'), ('ምናምን', 'ኢቲዮ'), ('ኢቲዮ', 'ቴሌኮም'), ('ቴሌኮም', 'እናመሰግናለን'), ('እናመሰግናለን', 'ብዙ'), ('ብዙ', 'ለውጥ'), ('ለውጥ', 'አለ'), ('አለ', 'ነገርግን'), ('ነገርግን', 'ብዙ'), ('ብዙ', 'ካርድ'), ('ካርድ', 'ለሚጠቀሙ'), ('ለሚጠቀሙ', 'ደንበኞች'), ('ደንበኞች', 'ልዩ'), ('ልዩ', 'ሽልማት'), ('ሽልማት', 'ብታዘጋጁ')]
#
#
# Comment: ለአንድ ቀን
# Tokens: ['ለአንድ', 'ቀን']
# 2-Grams: [('ለአንድ', 'ቀን')]
#
#
# Comment: አሽቃባጭ diaspora ስታዩ አይደል
# Tokens: ['አሽቃባጭ', 'diaspora', 'ስታዩ', 'አይደል']
# 2-Grams: [('አሽቃባጭ', 'diaspora'), ('diaspora', 'ስታዩ'), ('ስታዩ', 'አይደል')]
#
#
# Comment: what great do same internet
# Tokens: ['what', 'great', 'do', 'same', 'internet']
# 2-Grams: [('what', 'great'), ('great', 'do'), ('do', 'same'), ('same', 'internet')]
#
#
# Comment: እለታዊ ያለገደብ የኢንተርኔት ጥቅልም ቢኖር አሪፍ ይመስለኛል
# Tokens: ['እለታዊ', 'ያለገደብ', 'የኢንተርኔት', 'ጥቅልም', 'ቢኖር', 'አሪፍ', 'ይመስለኛል']
# 2-Grams: [('እለታዊ', 'ያለገደብ'), ('ያለገደብ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ጥቅልም'), ('ጥቅልም', 'ቢኖር'), ('ቢኖር', 'አሪፍ'), ('አሪፍ', 'ይመስለኛል')]
#
#
# Comment: በጣም ደስ ይላል የኢንተርኔት ወጪ ያልቻልነው
# Tokens: ['በጣም', 'ደስ', 'ይላል', 'የኢንተርኔት', 'ወጪ', 'ያልቻልነው']
# 2-Grams: [('በጣም', 'ደስ'), ('ደስ', 'ይላል'), ('ይላል', 'የኢንተርኔት'), ('የኢንተርኔት', 'ወጪ'), ('ወጪ', 'ያልቻልነው')]
#
#
# Comment: im not believe telebirr can not focus disabled person telecom
# Tokens: ['im', 'not', 'believe', 'telebirr', 'can', 'not', 'focus', 'disabled', 'person', 'telecom']
# 2-Grams: [('im', 'not'), ('not', 'believe'), ('believe', 'telebirr'), ('telebirr', 'can'), ('can', 'not'), ('not', 'focus'), ('focus', 'disabled'), ('disabled', 'person'), ('person', 'telecom')]
#
#
# Comment: እለታዊ unlimited ኢንተርኔት ቢኖር more አሪፍ thank
# Tokens: ['እለታዊ', 'unlimited', 'ኢንተርኔት', 'ቢኖር', 'more', 'አሪፍ', 'thank']
# 2-Grams: [('እለታዊ', 'unlimited'), ('unlimited', 'ኢንተርኔት'), ('ኢንተርኔት', 'ቢኖር'), ('ቢኖር', 'more'), ('more', 'አሪፍ'), ('አሪፍ', 'thank')]
#
#
# Comment: ጥሩ እይታ
# Tokens: ['ጥሩ', 'እይታ']
# 2-Grams: [('ጥሩ', 'እይታ')]
#
#
# Comment: ያልተገደበ ጥሩ እልል
# Tokens: ['ያልተገደበ', 'ጥሩ', 'እልል']
# 2-Grams: [('ያልተገደበ', 'ጥሩ'), ('ጥሩ', 'እልል')]
#
#
# Comment: ጀንጃኝ ቀን ወጣለታ ማዝነው ለጆሮ ለማንኛዉም እናመሰግናለን ethio telecom
# Tokens: ['ጀንጃኝ', 'ቀን', 'ወጣለታ', 'ማዝነው', 'ለጆሮ', 'ለማንኛዉም', 'እናመሰግናለን', 'ethio', 'telecom']
# 2-Grams: [('ጀንጃኝ', 'ቀን'), ('ቀን', 'ወጣለታ'), ('ወጣለታ', 'ማዝነው'), ('ማዝነው', 'ለጆሮ'), ('ለጆሮ', 'ለማንኛዉም'), ('ለማንኛዉም', 'እናመሰግናለን'), ('እናመሰግናለን', 'ethio'), ('ethio', 'telecom')]
#
#
# Comment: ቴሌብር አጠቀቃም አልገባኝም ቴሌ ቤት ወይንም በንክ ቤት ሄጄነው የሚመዘገበዉ
# Tokens: ['ቴሌብር', 'አጠቀቃም', 'አልገባኝም', 'ቴሌ', 'ቤት', 'ወይንም', 'በንክ', 'ቤት', 'ሄጄነው', 'የሚመዘገበዉ']
# 2-Grams: [('ቴሌብር', 'አጠቀቃም'), ('አጠቀቃም', 'አልገባኝም'), ('አልገባኝም', 'ቴሌ'), ('ቴሌ', 'ቤት'), ('ቤት', 'ወይንም'), ('ወይንም', 'በንክ'), ('በንክ', 'ቤት'), ('ቤት', 'ሄጄነው'), ('ሄጄነው', 'የሚመዘገበዉ')]
#
#
# Comment: ድምፅ ብዙ አይጎዳም ኢንተርኔትም ብትጨምሩበት በጣም ተመራጭ
# Tokens: ['ድምፅ', 'ብዙ', 'አይጎዳም', 'ኢንተርኔትም', 'ብትጨምሩበት', 'በጣም', 'ተመራጭ']
# 2-Grams: [('ድምፅ', 'ብዙ'), ('ብዙ', 'አይጎዳም'), ('አይጎዳም', 'ኢንተርኔትም'), ('ኢንተርኔትም', 'ብትጨምሩበት'), ('ብትጨምሩበት', 'በጣም'), ('በጣም', 'ተመራጭ')]
#
#
# Comment: great job
# Tokens: ['great', 'job']
# 2-Grams: [('great', 'job')]
#
#
# Comment: የኢንተርኔት ጥቅልም ቢሆን መልካም
# Tokens: ['የኢንተርኔት', 'ጥቅልም', 'ቢሆን', 'መልካም']
# 2-Grams: [('የኢንተርኔት', 'ጥቅልም'), ('ጥቅልም', 'ቢሆን'), ('ቢሆን', 'መልካም')]
#
#
# Comment: ethio telecom exellent
# Tokens: ['ethio', 'telecom', 'exellent']
# 2-Grams: [('ethio', 'telecom'), ('telecom', 'exellent')]
#
#
# Comment: ok
# Tokens: ['ok']
# 2-Grams: []
#
#
# Comment: ወደዉጭ ሀገር መደወል ያስችላል
# Tokens: ['ወደዉጭ', 'ሀገር', 'መደወል', 'ያስችላል']
# 2-Grams: [('ወደዉጭ', 'ሀገር'), ('ሀገር', 'መደወል'), ('መደወል', 'ያስችላል')]
#
#
# Comment: የመደበኛ ባለገመድ ብሮድባንድ ኢንተርኔት አገልግሎት የማሻሻያ ዝርዝሩን ፈጠን አርጉት እንጂ
# Tokens: ['የመደበኛ', 'ባለገመድ', 'ብሮድባንድ', 'ኢንተርኔት', 'አገልግሎት', 'የማሻሻያ', 'ዝርዝሩን', 'ፈጠን', 'አርጉት', 'እንጂ']
# 2-Grams: [('የመደበኛ', 'ባለገመድ'), ('ባለገመድ', 'ብሮድባንድ'), ('ብሮድባንድ', 'ኢንተርኔት'), ('ኢንተርኔት', 'አገልግሎት'), ('አገልግሎት', 'የማሻሻያ'), ('የማሻሻያ', 'ዝርዝሩን'), ('ዝርዝሩን', 'ፈጠን'), ('ፈጠን', 'አርጉት'), ('አርጉት', 'እንጂ')]
#
#
# Comment: ወርሀዊ የኢንተርኔት ጥቅል ለይም ቅናሽ አድርጉ
# Tokens: ['ወርሀዊ', 'የኢንተርኔት', 'ጥቅል', 'ለይም', 'ቅናሽ', 'አድርጉ']
# 2-Grams: [('ወርሀዊ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ጥቅል'), ('ጥቅል', 'ለይም'), ('ለይም', 'ቅናሽ'), ('ቅናሽ', 'አድርጉ')]
#
#
# Comment: ቴሌ እያደረገ ያለው ተቋማዊ መሻሻል ይበረታታል በተያዙ አካባቢዎች ቶሎ አገልግሎት ማስጀመራችው መልካም የጥራት ችግሩን እየተከታተላችው ብትፈቱ የተሻለ
# Tokens: ['ቴሌ', 'እያደረገ', 'ያለው', 'ተቋማዊ', 'መሻሻል', 'ይበረታታል', 'በተያዙ', 'አካባቢዎች', 'ቶሎ', 'አገልግሎት', 'ማስጀመራችው', 'መልካም', 'የጥራት', 'ችግሩን', 'እየተከታተላችው', 'ብትፈቱ', 'የተሻለ']
# 2-Grams: [('ቴሌ', 'እያደረገ'), ('እያደረገ', 'ያለው'), ('ያለው', 'ተቋማዊ'), ('ተቋማዊ', 'መሻሻል'), ('መሻሻል', 'ይበረታታል'), ('ይበረታታል', 'በተያዙ'), ('በተያዙ', 'አካባቢዎች'), ('አካባቢዎች', 'ቶሎ'), ('ቶሎ', 'አገልግሎት'), ('አገልግሎት', 'ማስጀመራችው'), ('ማስጀመራችው', 'መልካም'), ('መልካም', 'የጥራት'), ('የጥራት', 'ችግሩን'), ('ችግሩን', 'እየተከታተላችው'), ('እየተከታተላችው', 'ብትፈቱ'), ('ብትፈቱ', 'የተሻለ')]
#
#
# Comment: የአመት ጥቅል የድምፅ ወይ የኢንተርኔት ያለ sms ቢዘጋጅ ዋጋ ተቀንሶ አሪፍ ይመስለኛል ሰሞኑ ወዳጄ ተሳስቶ የኢንተርኔት ገዝቶ መጣ መቀየር ደሞ አይቻልም ተባለ ሌላ ጭማሪ ወጪ ሆነበት ያለ sms ቢኖር ብቻውን ይገዛ ነበር
# Tokens: ['የአመት', 'ጥቅል', 'የድምፅ', 'ወይ', 'የኢንተርኔት', 'ያለ', 'sms', 'ቢዘጋጅ', 'ዋጋ', 'ተቀንሶ', 'አሪፍ', 'ይመስለኛል', 'ሰሞኑ', 'ወዳጄ', 'ተሳስቶ', 'የኢንተርኔት', 'ገዝቶ', 'መጣ', 'መቀየር', 'ደሞ', 'አይቻልም', 'ተባለ', 'ሌላ', 'ጭማሪ', 'ወጪ', 'ሆነበት', 'ያለ', 'sms', 'ቢኖር', 'ብቻውን', 'ይገዛ', 'ነበር']
# 2-Grams: [('የአመት', 'ጥቅል'), ('ጥቅል', 'የድምፅ'), ('የድምፅ', 'ወይ'), ('ወይ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ያለ'), ('ያለ', 'sms'), ('sms', 'ቢዘጋጅ'), ('ቢዘጋጅ', 'ዋጋ'), ('ዋጋ', 'ተቀንሶ'), ('ተቀንሶ', 'አሪፍ'), ('አሪፍ', 'ይመስለኛል'), ('ይመስለኛል', 'ሰሞኑ'), ('ሰሞኑ', 'ወዳጄ'), ('ወዳጄ', 'ተሳስቶ'), ('ተሳስቶ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ገዝቶ'), ('ገዝቶ', 'መጣ'), ('መጣ', 'መቀየር'), ('መቀየር', 'ደሞ'), ('ደሞ', 'አይቻልም'), ('አይቻልም', 'ተባለ'), ('ተባለ', 'ሌላ'), ('ሌላ', 'ጭማሪ'), ('ጭማሪ', 'ወጪ'), ('ወጪ', 'ሆነበት'), ('ሆነበት', 'ያለ'), ('ያለ', 'sms'), ('sms', 'ቢኖር'), ('ቢኖር', 'ብቻውን'), ('ብቻውን', 'ይገዛ'), ('ይገዛ', 'ነበር')]
#
#
# Comment: የኢንተርኔትም ቢኖር አሪፍ
# Tokens: ['የኢንተርኔትም', 'ቢኖር', 'አሪፍ']
# 2-Grams: [('የኢንተርኔትም', 'ቢኖር'), ('ቢኖር', 'አሪፍ')]
#
#
# Comment: nomore safari coming solve network service problem which distributed without discrimanting people live rular urban
# Tokens: ['nomore', 'safari', 'coming', 'solve', 'network', 'service', 'problem', 'which', 'distributed', 'without', 'discrimanting', 'people', 'live', 'rular', 'urban']
# 2-Grams: [('nomore', 'safari'), ('safari', 'coming'), ('coming', 'solve'), ('solve', 'network'), ('network', 'service'), ('service', 'problem'), ('problem', 'which'), ('which', 'distributed'), ('distributed', 'without'), ('without', 'discrimanting'), ('discrimanting', 'people'), ('people', 'live'), ('live', 'rular'), ('rular', 'urban')]
#
#
# Comment: ethio tele በጣም እናመሰግናለን የኢንተርኔትም ቢኖር
# Tokens: ['ethio', 'tele', 'በጣም', 'እናመሰግናለን', 'የኢንተርኔትም', 'ቢኖር']
# 2-Grams: [('ethio', 'tele'), ('tele', 'በጣም'), ('በጣም', 'እናመሰግናለን'), ('እናመሰግናለን', 'የኢንተርኔትም'), ('የኢንተርኔትም', 'ቢኖር')]
#
#
# Comment: በጣም ጡሩ myethio telecome
# Tokens: ['በጣም', 'ጡሩ', 'myethio', 'telecome']
# 2-Grams: [('በጣም', 'ጡሩ'), ('ጡሩ', 'myethio'), ('myethio', 'telecome')]
#
#
# Comment: tell bir registered ቢያረገኝም መጠቀም አልቻልኩም
# Tokens: ['tell', 'bir', 'registered', 'ቢያረገኝም', 'መጠቀም', 'አልቻልኩም']
# 2-Grams: [('tell', 'bir'), ('bir', 'registered'), ('registered', 'ቢያረገኝም'), ('ቢያረገኝም', 'መጠቀም'), ('መጠቀም', 'አልቻልኩም')]
#
#
# Comment: በጣም ጥሩ በርቱ ቆያቹ
# Tokens: ['በጣም', 'ጥሩ', 'በርቱ', 'ቆያቹ']
# 2-Grams: [('በጣም', 'ጥሩ'), ('ጥሩ', 'በርቱ'), ('በርቱ', 'ቆያቹ')]
#
#
# Comment: ጥሩ ነገርግን ጥቅል የለም እኮ ከመቼ ጀምሮ ስራ የሚዉለዉ
# Tokens: ['ጥሩ', 'ነገርግን', 'ጥቅል', 'የለም', 'እኮ', 'ከመቼ', 'ጀምሮ', 'ስራ', 'የሚዉለዉ']
# 2-Grams: [('ጥሩ', 'ነገርግን'), ('ነገርግን', 'ጥቅል'), ('ጥቅል', 'የለም'), ('የለም', 'እኮ'), ('እኮ', 'ከመቼ'), ('ከመቼ', 'ጀምሮ'), ('ጀምሮ', 'ስራ'), ('ስራ', 'የሚዉለዉ')]
#
#
# Comment: የኢንተርኔት ዳታ አማራ ክልል እስካሁን ድረስ እንደተዘጋ እባክዎትን ይልቀቁልን መንግስት ረስቶት ከሆነ አሳስቡት እስኪ ብዙ ጉዳይ ስላለበት መንግስት እኮ ሊረሳ ይችላል
# Tokens: ['የኢንተርኔት', 'ዳታ', 'አማራ', 'ክልል', 'እስካሁን', 'ድረስ', 'እንደተዘጋ', 'እባክዎትን', 'ይልቀቁልን', 'መንግስት', 'ረስቶት', 'ከሆነ', 'አሳስቡት', 'እስኪ', 'ብዙ', 'ጉዳይ', 'ስላለበት', 'መንግስት', 'እኮ', 'ሊረሳ', 'ይችላል']
# 2-Grams: [('የኢንተርኔት', 'ዳታ'), ('ዳታ', 'አማራ'), ('አማራ', 'ክልል'), ('ክልል', 'እስካሁን'), ('እስካሁን', 'ድረስ'), ('ድረስ', 'እንደተዘጋ'), ('እንደተዘጋ', 'እባክዎትን'), ('እባክዎትን', 'ይልቀቁልን'), ('ይልቀቁልን', 'መንግስት'), ('መንግስት', 'ረስቶት'), ('ረስቶት', 'ከሆነ'), ('ከሆነ', 'አሳስቡት'), ('አሳስቡት', 'እስኪ'), ('እስኪ', 'ብዙ'), ('ብዙ', 'ጉዳይ'), ('ጉዳይ', 'ስላለበት'), ('ስላለበት', 'መንግስት'), ('መንግስት', 'እኮ'), ('እኮ', 'ሊረሳ'), ('ሊረሳ', 'ይችላል')]
#
#
# Comment: የኢንተርኔት እንደዚህ አምጡልን
# Tokens: ['የኢንተርኔት', 'እንደዚህ', 'አምጡልን']
# 2-Grams: [('የኢንተርኔት', 'እንደዚህ'), ('እንደዚህ', 'አምጡልን')]
#
#
# Comment: thanks እናመሰግናለን
# Tokens: ['thanks', 'እናመሰግናለን']
# 2-Grams: [('thanks', 'እናመሰግናለን')]
#
#
# Comment: ተሸላሚዎች ዝርዝር ውስጥ ስሜ አለ ሽልማቱ አልደረሰኝም ይሄ ምን የሚሉት ማጭበርበር አረ በመንግስት እምነት አታሳጡን
# Tokens: ['ተሸላሚዎች', 'ዝርዝር', 'ውስጥ', 'ስሜ', 'አለ', 'ሽልማቱ', 'አልደረሰኝም', 'ይሄ', 'ምን', 'የሚሉት', 'ማጭበርበር', 'አረ', 'በመንግስት', 'እምነት', 'አታሳጡን']
# 2-Grams: [('ተሸላሚዎች', 'ዝርዝር'), ('ዝርዝር', 'ውስጥ'), ('ውስጥ', 'ስሜ'), ('ስሜ', 'አለ'), ('አለ', 'ሽልማቱ'), ('ሽልማቱ', 'አልደረሰኝም'), ('አልደረሰኝም', 'ይሄ'), ('ይሄ', 'ምን'), ('ምን', 'የሚሉት'), ('የሚሉት', 'ማጭበርበር'), ('ማጭበርበር', 'አረ'), ('አረ', 'በመንግስት'), ('በመንግስት', 'እምነት'), ('እምነት', 'አታሳጡን')]
#
#
# Comment: can not buy package using telebirr apps informed center today
# Tokens: ['can', 'not', 'buy', 'package', 'using', 'telebirr', 'apps', 'informed', 'center', 'today']
# 2-Grams: [('can', 'not'), ('not', 'buy'), ('buy', 'package'), ('package', 'using'), ('using', 'telebirr'), ('telebirr', 'apps'), ('apps', 'informed'), ('informed', 'center'), ('center', 'today')]
#
#
# Comment: thanks
# Tokens: ['thanks']
# 2-Grams: []
#
#
# Comment: ተንቀሳቃሽ wifi ለምን አልሰራልኝም ከትናንት ጀምሮ
# Tokens: ['ተንቀሳቃሽ', 'wifi', 'ለምን', 'አልሰራልኝም', 'ከትናንት', 'ጀምሮ']
# 2-Grams: [('ተንቀሳቃሽ', 'wifi'), ('wifi', 'ለምን'), ('ለምን', 'አልሰራልኝም'), ('አልሰራልኝም', 'ከትናንት'), ('ከትናንት', 'ጀምሮ')]
#
#
# Comment: የተመረጡ super ማርኬቶች የቲኞቹ
# Tokens: ['የተመረጡ', 'super', 'ማርኬቶች', 'የቲኞቹ']
# 2-Grams: [('የተመረጡ', 'super'), ('super', 'ማርኬቶች'), ('ማርኬቶች', 'የቲኞቹ')]
#
#
# Comment: እንዴት ለሰው ስጦታ መላክ እንችላለን
# Tokens: ['እንዴት', 'ለሰው', 'ስጦታ', 'መላክ', 'እንችላለን']
# 2-Grams: [('እንዴት', 'ለሰው'), ('ለሰው', 'ስጦታ'), ('ስጦታ', 'መላክ'), ('መላክ', 'እንችላለን')]
#
#
# Comment: package የለም ማለቴ የኢንተርኔት ወይም የድምፅ ቀናሽ አልተደረገም መግዛት አይችልም
# Tokens: ['package', 'የለም', 'ማለቴ', 'የኢንተርኔት', 'ወይም', 'የድምፅ', 'ቀናሽ', 'አልተደረገም', 'መግዛት', 'አይችልም']
# 2-Grams: [('package', 'የለም'), ('የለም', 'ማለቴ'), ('ማለቴ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ወይም'), ('ወይም', 'የድምፅ'), ('የድምፅ', 'ቀናሽ'), ('ቀናሽ', 'አልተደረገም'), ('አልተደረገም', 'መግዛት'), ('መግዛት', 'አይችልም')]
#
#
# Comment: ብትጀምሩ
# Tokens: ['ብትጀምሩ']
# 2-Grams: []
#
#
# Comment: transaction fee እጅግ በጣም ዉድ
# Tokens: ['transaction', 'fee', 'እጅግ', 'በጣም', 'ዉድ']
# 2-Grams: [('transaction', 'fee'), ('fee', 'እጅግ'), ('እጅግ', 'በጣም'), ('በጣም', 'ዉድ')]
#
#
# Comment: በቴሌብር ሲገበያዩ ከብር ዝርፊያና ከፎርጅድ ስጋቶች ነፃ ሆኖ መገበያየት ሳይሆን ፎርጅድ የብር ኖቶች ገበያ እንዳይቀላቀሉ በማድረግ የገበያ ቀውስ እንዳይፈጠር መከላከልም ጭምር
# Tokens: ['በቴሌብር', 'ሲገበያዩ', 'ከብር', 'ዝርፊያና', 'ከፎርጅድ', 'ስጋቶች', 'ነፃ', 'ሆኖ', 'መገበያየት', 'ሳይሆን', 'ፎርጅድ', 'የብር', 'ኖቶች', 'ገበያ', 'እንዳይቀላቀሉ', 'በማድረግ', 'የገበያ', 'ቀውስ', 'እንዳይፈጠር', 'መከላከልም', 'ጭምር']
# 2-Grams: [('በቴሌብር', 'ሲገበያዩ'), ('ሲገበያዩ', 'ከብር'), ('ከብር', 'ዝርፊያና'), ('ዝርፊያና', 'ከፎርጅድ'), ('ከፎርጅድ', 'ስጋቶች'), ('ስጋቶች', 'ነፃ'), ('ነፃ', 'ሆኖ'), ('ሆኖ', 'መገበያየት'), ('መገበያየት', 'ሳይሆን'), ('ሳይሆን', 'ፎርጅድ'), ('ፎርጅድ', 'የብር'), ('የብር', 'ኖቶች'), ('ኖቶች', 'ገበያ'), ('ገበያ', 'እንዳይቀላቀሉ'), ('እንዳይቀላቀሉ', 'በማድረግ'), ('በማድረግ', 'የገበያ'), ('የገበያ', 'ቀውስ'), ('ቀውስ', 'እንዳይፈጠር'), ('እንዳይፈጠር', 'መከላከልም'), ('መከላከልም', 'ጭምር')]
#
#
# Comment: ሽልማቱስ
# Tokens: ['ሽልማቱስ']
# 2-Grams: []
#
#
# Comment: የቴሌብር ቋሚ ደንበኛ በርቱ ብታሻሽሉት የምትሰጡት ዋጋ ቢኖረው ስጥታውን ሳልጠቀም እየተቃጠለብኝ ስለሆነ ተቃጠለብኝ አዬኔ እያየ
# Tokens: ['የቴሌብር', 'ቋሚ', 'ደንበኛ', 'በርቱ', 'ብታሻሽሉት', 'የምትሰጡት', 'ዋጋ', 'ቢኖረው', 'ስጥታውን', 'ሳልጠቀም', 'እየተቃጠለብኝ', 'ስለሆነ', 'ተቃጠለብኝ', 'አዬኔ', 'እያየ']
# 2-Grams: [('የቴሌብር', 'ቋሚ'), ('ቋሚ', 'ደንበኛ'), ('ደንበኛ', 'በርቱ'), ('በርቱ', 'ብታሻሽሉት'), ('ብታሻሽሉት', 'የምትሰጡት'), ('የምትሰጡት', 'ዋጋ'), ('ዋጋ', 'ቢኖረው'), ('ቢኖረው', 'ስጥታውን'), ('ስጥታውን', 'ሳልጠቀም'), ('ሳልጠቀም', 'እየተቃጠለብኝ'), ('እየተቃጠለብኝ', 'ስለሆነ'), ('ስለሆነ', 'ተቃጠለብኝ'), ('ተቃጠለብኝ', 'አዬኔ'), ('አዬኔ', 'እያየ')]
#
#
# Comment: ለሸገሮች ማለቴ ሱፐርማርኬቶቹ
# Tokens: ['ለሸገሮች', 'ማለቴ', 'ሱፐርማርኬቶቹ']
# 2-Grams: [('ለሸገሮች', 'ማለቴ'), ('ማለቴ', 'ሱፐርማርኬቶቹ')]
#
#
# Comment: ካርድን ቴሌብር ማስተላለፍ ይቻላል
# Tokens: ['ካርድን', 'ቴሌብር', 'ማስተላለፍ', 'ይቻላል']
# 2-Grams: [('ካርድን', 'ቴሌብር'), ('ቴሌብር', 'ማስተላለፍ'), ('ማስተላለፍ', 'ይቻላል')]
#
#
# Comment: telebirr best
# Tokens: ['telebirr', 'best']
# 2-Grams: [('telebirr', 'best')]
#
#
# Comment: ሽልማቱ ምን ሆነ
# Tokens: ['ሽልማቱ', 'ምን', 'ሆነ']
# 2-Grams: [('ሽልማቱ', 'ምን'), ('ምን', 'ሆነ')]
#
#
# Comment: standardize የሆነ የዋጋ ተመን የምርትና አገልግሎት ጥራት በሌለበት ሀገር ፐርሰንት ማስቀመጥ መካሪ ማጣት ይመስልባችኋል ይሄንን ትታችሁ ያላግባብ የሚቆረጠውን ባስተካከላችሁ ደስ ባለን
# Tokens: ['standardize', 'የሆነ', 'የዋጋ', 'ተመን', 'የምርትና', 'አገልግሎት', 'ጥራት', 'በሌለበት', 'ሀገር', 'ፐርሰንት', 'ማስቀመጥ', 'መካሪ', 'ማጣት', 'ይመስልባችኋል', 'ይሄንን', 'ትታችሁ', 'ያላግባብ', 'የሚቆረጠውን', 'ባስተካከላችሁ', 'ደስ', 'ባለን']
# 2-Grams: [('standardize', 'የሆነ'), ('የሆነ', 'የዋጋ'), ('የዋጋ', 'ተመን'), ('ተመን', 'የምርትና'), ('የምርትና', 'አገልግሎት'), ('አገልግሎት', 'ጥራት'), ('ጥራት', 'በሌለበት'), ('በሌለበት', 'ሀገር'), ('ሀገር', 'ፐርሰንት'), ('ፐርሰንት', 'ማስቀመጥ'), ('ማስቀመጥ', 'መካሪ'), ('መካሪ', 'ማጣት'), ('ማጣት', 'ይመስልባችኋል'), ('ይመስልባችኋል', 'ይሄንን'), ('ይሄንን', 'ትታችሁ'), ('ትታችሁ', 'ያላግባብ'), ('ያላግባብ', 'የሚቆረጠውን'), ('የሚቆረጠውን', 'ባስተካከላችሁ'), ('ባስተካከላችሁ', 'ደስ'), ('ደስ', 'ባለን')]
#
#
# Comment: አረ ቶሎ ሸልሙን package
# Tokens: ['አረ', 'ቶሎ', 'ሸልሙን', 'package']
# 2-Grams: [('አረ', 'ቶሎ'), ('ቶሎ', 'ሸልሙን'), ('ሸልሙን', 'package')]
#
#
# Comment: ማሻሻያ እያየን
# Tokens: ['ማሻሻያ', 'እያየን']
# 2-Grams: [('ማሻሻያ', 'እያየን')]
#
#
# Comment: ይበልጥ ጥራት ብትሰሩ ይሻላል ከጥራት ቅናሽ ብትመጡ
# Tokens: ['ይበልጥ', 'ጥራት', 'ብትሰሩ', 'ይሻላል', 'ከጥራት', 'ቅናሽ', 'ብትመጡ']
# 2-Grams: [('ይበልጥ', 'ጥራት'), ('ጥራት', 'ብትሰሩ'), ('ብትሰሩ', 'ይሻላል'), ('ይሻላል', 'ከጥራት'), ('ከጥራት', 'ቅናሽ'), ('ቅናሽ', 'ብትመጡ')]
#
#
# Comment: እየታየኝ ያለው ችግር ለህብረተሰቡ step step ማሳየት ማስተማር ይገባችኋል
# Tokens: ['እየታየኝ', 'ያለው', 'ችግር', 'ለህብረተሰቡ', 'step', 'step', 'ማሳየት', 'ማስተማር', 'ይገባችኋል']
# 2-Grams: [('እየታየኝ', 'ያለው'), ('ያለው', 'ችግር'), ('ችግር', 'ለህብረተሰቡ'), ('ለህብረተሰቡ', 'step'), ('step', 'step'), ('step', 'ማሳየት'), ('ማሳየት', 'ማስተማር'), ('ማስተማር', 'ይገባችኋል')]
#
#
# Comment: ሽልማቱን አድርሱና ሌላ መጣ ኮ
# Tokens: ['ሽልማቱን', 'አድርሱና', 'ሌላ', 'መጣ', 'ኮ']
# 2-Grams: [('ሽልማቱን', 'አድርሱና'), ('አድርሱና', 'ሌላ'), ('ሌላ', 'መጣ'), ('መጣ', 'ኮ')]
#
#
# Comment: ይቅርታ በሂሳብ እንቅስቃሴው ያስገቡት የብር መጠን ከእለት ገደብዎ የሚያሳልፍዎት እባክዎ ዝቅተኛ መጠን ያስገቡ ወይም ነገ በድጋሚ ይሞክሩ በቴሌብር ስለተገለገሉ እናመሰግናለን ኢትዮ ቴሌኮም ለምንድነው እንደዚ የሚለው ግብይት ሳደርግ የቀን ገደብ አለው እንዴ
# Tokens: ['ይቅርታ', 'በሂሳብ', 'እንቅስቃሴው', 'ያስገቡት', 'የብር', 'መጠን', 'ከእለት', 'ገደብዎ', 'የሚያሳልፍዎት', 'እባክዎ', 'ዝቅተኛ', 'መጠን', 'ያስገቡ', 'ወይም', 'ነገ', 'በድጋሚ', 'ይሞክሩ', 'በቴሌብር', 'ስለተገለገሉ', 'እናመሰግናለን', 'ኢትዮ', 'ቴሌኮም', 'ለምንድነው', 'እንደዚ', 'የሚለው', 'ግብይት', 'ሳደርግ', 'የቀን', 'ገደብ', 'አለው', 'እንዴ']
# 2-Grams: [('ይቅርታ', 'በሂሳብ'), ('በሂሳብ', 'እንቅስቃሴው'), ('እንቅስቃሴው', 'ያስገቡት'), ('ያስገቡት', 'የብር'), ('የብር', 'መጠን'), ('መጠን', 'ከእለት'), ('ከእለት', 'ገደብዎ'), ('ገደብዎ', 'የሚያሳልፍዎት'), ('የሚያሳልፍዎት', 'እባክዎ'), ('እባክዎ', 'ዝቅተኛ'), ('ዝቅተኛ', 'መጠን'), ('መጠን', 'ያስገቡ'), ('ያስገቡ', 'ወይም'), ('ወይም', 'ነገ'), ('ነገ', 'በድጋሚ'), ('በድጋሚ', 'ይሞክሩ'), ('ይሞክሩ', 'በቴሌብር'), ('በቴሌብር', 'ስለተገለገሉ'), ('ስለተገለገሉ', 'እናመሰግናለን'), ('እናመሰግናለን', 'ኢትዮ'), ('ኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'ለምንድነው'), ('ለምንድነው', 'እንደዚ'), ('እንደዚ', 'የሚለው'), ('የሚለው', 'ግብይት'), ('ግብይት', 'ሳደርግ'), ('ሳደርግ', 'የቀን'), ('የቀን', 'ገደብ'), ('ገደብ', 'አለው'), ('አለው', 'እንዴ')]
#
#
# Comment: password እረስቼው ነበር ለማስተካከል እምቢ አለኝ መፍትሄ ካላቹ
# Tokens: ['password', 'እረስቼው', 'ነበር', 'ለማስተካከል', 'እምቢ', 'አለኝ', 'መፍትሄ', 'ካላቹ']
# 2-Grams: [('password', 'እረስቼው'), ('እረስቼው', 'ነበር'), ('ነበር', 'ለማስተካከል'), ('ለማስተካከል', 'እምቢ'), ('እምቢ', 'አለኝ'), ('አለኝ', 'መፍትሄ'), ('መፍትሄ', 'ካላቹ')]
#
#
# Comment: ዉድ ቴሌዎች መጥፎ ስራ እየሰራችሁ ስለሆኔ ከድርግታችሁ እንድትቆጥቡ እናሳስባለን የማታደሬጉት ነገር እናደርጋለን ብላችሁ ቃል አንዳትገቡ ሽልማቱ ዉስጥ ነበሬ ስንጠይቅ ለባለ እድለኞች ትላላቹ ቆይ ተሳስታችሁ መእልክት የላካችሁኝ
# Tokens: ['ዉድ', 'ቴሌዎች', 'መጥፎ', 'ስራ', 'እየሰራችሁ', 'ስለሆኔ', 'ከድርግታችሁ', 'እንድትቆጥቡ', 'እናሳስባለን', 'የማታደሬጉት', 'ነገር', 'እናደርጋለን', 'ብላችሁ', 'ቃል', 'አንዳትገቡ', 'ሽልማቱ', 'ዉስጥ', 'ነበሬ', 'ስንጠይቅ', 'ለባለ', 'እድለኞች', 'ትላላቹ', 'ቆይ', 'ተሳስታችሁ', 'መእልክት', 'የላካችሁኝ']
# 2-Grams: [('ዉድ', 'ቴሌዎች'), ('ቴሌዎች', 'መጥፎ'), ('መጥፎ', 'ስራ'), ('ስራ', 'እየሰራችሁ'), ('እየሰራችሁ', 'ስለሆኔ'), ('ስለሆኔ', 'ከድርግታችሁ'), ('ከድርግታችሁ', 'እንድትቆጥቡ'), ('እንድትቆጥቡ', 'እናሳስባለን'), ('እናሳስባለን', 'የማታደሬጉት'), ('የማታደሬጉት', 'ነገር'), ('ነገር', 'እናደርጋለን'), ('እናደርጋለን', 'ብላችሁ'), ('ብላችሁ', 'ቃል'), ('ቃል', 'አንዳትገቡ'), ('አንዳትገቡ', 'ሽልማቱ'), ('ሽልማቱ', 'ዉስጥ'), ('ዉስጥ', 'ነበሬ'), ('ነበሬ', 'ስንጠይቅ'), ('ስንጠይቅ', 'ለባለ'), ('ለባለ', 'እድለኞች'), ('እድለኞች', 'ትላላቹ'), ('ትላላቹ', 'ቆይ'), ('ቆይ', 'ተሳስታችሁ'), ('ተሳስታችሁ', 'መእልክት'), ('መእልክት', 'የላካችሁኝ')]
#
#
# Comment: በቴሌብር ሲገበያዩ ለብር ኖቶች ህትመት የሚወጣውን በርካታ ዶላሮች በማስቀረት ለአገራችን እድገት አስተዋፅኦ እያደረጉ መሆኑን ልብ ይበሉ
# Tokens: ['በቴሌብር', 'ሲገበያዩ', 'ለብር', 'ኖቶች', 'ህትመት', 'የሚወጣውን', 'በርካታ', 'ዶላሮች', 'በማስቀረት', 'ለአገራችን', 'እድገት', 'አስተዋፅኦ', 'እያደረጉ', 'መሆኑን', 'ልብ', 'ይበሉ']
# 2-Grams: [('በቴሌብር', 'ሲገበያዩ'), ('ሲገበያዩ', 'ለብር'), ('ለብር', 'ኖቶች'), ('ኖቶች', 'ህትመት'), ('ህትመት', 'የሚወጣውን'), ('የሚወጣውን', 'በርካታ'), ('በርካታ', 'ዶላሮች'), ('ዶላሮች', 'በማስቀረት'), ('በማስቀረት', 'ለአገራችን'), ('ለአገራችን', 'እድገት'), ('እድገት', 'አስተዋፅኦ'), ('አስተዋፅኦ', 'እያደረጉ'), ('እያደረጉ', 'መሆኑን'), ('መሆኑን', 'ልብ'), ('ልብ', 'ይበሉ')]
#
#
# Comment: የኢንተርኔት ዳታ አማራ ክልል እስካሁን ድረስ እንደተዘጋ እባክዎትን ይልቀቁልን መንግስት ረስቶት ከሆነ አሳስቡት እስኪ ብዙ ጉዳይ ስላለበት መንግስት እኮ ሊረሳ ይችላል
# Tokens: ['የኢንተርኔት', 'ዳታ', 'አማራ', 'ክልል', 'እስካሁን', 'ድረስ', 'እንደተዘጋ', 'እባክዎትን', 'ይልቀቁልን', 'መንግስት', 'ረስቶት', 'ከሆነ', 'አሳስቡት', 'እስኪ', 'ብዙ', 'ጉዳይ', 'ስላለበት', 'መንግስት', 'እኮ', 'ሊረሳ', 'ይችላል']
# 2-Grams: [('የኢንተርኔት', 'ዳታ'), ('ዳታ', 'አማራ'), ('አማራ', 'ክልል'), ('ክልል', 'እስካሁን'), ('እስካሁን', 'ድረስ'), ('ድረስ', 'እንደተዘጋ'), ('እንደተዘጋ', 'እባክዎትን'), ('እባክዎትን', 'ይልቀቁልን'), ('ይልቀቁልን', 'መንግስት'), ('መንግስት', 'ረስቶት'), ('ረስቶት', 'ከሆነ'), ('ከሆነ', 'አሳስቡት'), ('አሳስቡት', 'እስኪ'), ('እስኪ', 'ብዙ'), ('ብዙ', 'ጉዳይ'), ('ጉዳይ', 'ስላለበት'), ('ስላለበት', 'መንግስት'), ('መንግስት', 'እኮ'), ('እኮ', 'ሊረሳ'), ('ሊረሳ', 'ይችላል')]
#
#
# Comment: ethiotelecom ለምታረጉልን ጥረት ምሰጋና ይገባቿል ነገርግን በቴሌብር መጠቀም እንደኔላሉ ድሃዎች ስለምያስቸግር yimulu ሁሉምዜጋ የምገለገልበት አየርሰኣት የምንሰራበት አሰራር ብዘጋጅልን ጥሩነበር
# Tokens: ['ethiotelecom', 'ለምታረጉልን', 'ጥረት', 'ምሰጋና', 'ይገባቿል', 'ነገርግን', 'በቴሌብር', 'መጠቀም', 'እንደኔላሉ', 'ድሃዎች', 'ስለምያስቸግር', 'yimulu', 'ሁሉምዜጋ', 'የምገለገልበት', 'አየርሰኣት', 'የምንሰራበት', 'አሰራር', 'ብዘጋጅልን', 'ጥሩነበር']
# 2-Grams: [('ethiotelecom', 'ለምታረጉልን'), ('ለምታረጉልን', 'ጥረት'), ('ጥረት', 'ምሰጋና'), ('ምሰጋና', 'ይገባቿል'), ('ይገባቿል', 'ነገርግን'), ('ነገርግን', 'በቴሌብር'), ('በቴሌብር', 'መጠቀም'), ('መጠቀም', 'እንደኔላሉ'), ('እንደኔላሉ', 'ድሃዎች'), ('ድሃዎች', 'ስለምያስቸግር'), ('ስለምያስቸግር', 'yimulu'), ('yimulu', 'ሁሉምዜጋ'), ('ሁሉምዜጋ', 'የምገለገልበት'), ('የምገለገልበት', 'አየርሰኣት'), ('አየርሰኣት', 'የምንሰራበት'), ('የምንሰራበት', 'አሰራር'), ('አሰራር', 'ብዘጋጅልን'), ('ብዘጋጅልን', 'ጥሩነበር')]
#
#
# Comment: possible connect telebirr betting sites possible how which betting
# Tokens: ['possible', 'connect', 'telebirr', 'betting', 'sites', 'possible', 'how', 'which', 'betting']
# 2-Grams: [('possible', 'connect'), ('connect', 'telebirr'), ('telebirr', 'betting'), ('betting', 'sites'), ('sites', 'possible'), ('possible', 'how'), ('how', 'which'), ('which', 'betting')]
#
#
# Comment: make unlimited daily internet package
# Tokens: ['make', 'unlimited', 'daily', 'internet', 'package']
# 2-Grams: [('make', 'unlimited'), ('unlimited', 'daily'), ('daily', 'internet'), ('internet', 'package')]
#
#
# Comment: ያለ ገደብ ኢንተርኔት ብትጀምሩ ጥሩ
# Tokens: ['ያለ', 'ገደብ', 'ኢንተርኔት', 'ብትጀምሩ', 'ጥሩ']
# 2-Grams: [('ያለ', 'ገደብ'), ('ገደብ', 'ኢንተርኔት'), ('ኢንተርኔት', 'ብትጀምሩ'), ('ብትጀምሩ', 'ጥሩ')]
#
#
# Comment: unavailable
# Tokens: ['unavailable']
# 2-Grams: []
#
#
# Comment: የደግነት ጥግ
# Tokens: ['የደግነት', 'ጥግ']
# 2-Grams: [('የደግነት', 'ጥግ')]
#
#
# Comment: need high speed internet
# Tokens: ['need', 'high', 'speed', 'internet']
# 2-Grams: [('need', 'high'), ('high', 'speed'), ('speed', 'internet')]
#
#
# Comment: what great do same internet
# Tokens: ['what', 'great', 'do', 'same', 'internet']
# 2-Grams: [('what', 'great'), ('great', 'do'), ('do', 'same'), ('same', 'internet')]
#
#
# Comment: please make big discount flexi package than others unless going leave telecom just search better
# Tokens: ['please', 'make', 'big', 'discount', 'flexi', 'package', 'than', 'others', 'unless', 'going', 'leave', 'telecom', 'just', 'search', 'better']
# 2-Grams: [('please', 'make'), ('make', 'big'), ('big', 'discount'), ('discount', 'flexi'), ('flexi', 'package'), ('package', 'than'), ('than', 'others'), ('others', 'unless'), ('unless', 'going'), ('going', 'leave'), ('leave', 'telecom'), ('telecom', 'just'), ('just', 'search'), ('search', 'better')]
#
#
# Comment: good job
# Tokens: ['good', 'job']
# 2-Grams: [('good', 'job')]
#
#
# Comment: ሁሌም እርምጃ ቀዳሚ ጉዞ ከፍታ ዘመን ከኢትዮ ቴሌ ጋር
# Tokens: ['ሁሌም', 'እርምጃ', 'ቀዳሚ', 'ጉዞ', 'ከፍታ', 'ዘመን', 'ከኢትዮ', 'ቴሌ', 'ጋር']
# 2-Grams: [('ሁሌም', 'እርምጃ'), ('እርምጃ', 'ቀዳሚ'), ('ቀዳሚ', 'ጉዞ'), ('ጉዞ', 'ከፍታ'), ('ከፍታ', 'ዘመን'), ('ዘመን', 'ከኢትዮ'), ('ከኢትዮ', 'ቴሌ'), ('ቴሌ', 'ጋር')]
#
#
# Comment: nice prices electronic every shops expensive please reduce price supply more wireless wifi routers expensive found rare
# Tokens: ['nice', 'prices', 'electronic', 'every', 'shops', 'expensive', 'please', 'reduce', 'price', 'supply', 'more', 'wireless', 'wifi', 'routers', 'expensive', 'found', 'rare']
# 2-Grams: [('nice', 'prices'), ('prices', 'electronic'), ('electronic', 'every'), ('every', 'shops'), ('shops', 'expensive'), ('expensive', 'please'), ('please', 'reduce'), ('reduce', 'price'), ('price', 'supply'), ('supply', 'more'), ('more', 'wireless'), ('wireless', 'wifi'), ('wifi', 'routers'), ('routers', 'expensive'), ('expensive', 'found'), ('found', 'rare')]
#
#
# Comment: ኧረ ድምፅ አያሳስብም ኢንተርኔት በቅናሽ አመቻቹልን በአለም በጣም ውድ ኢንተርኔት ሀገር ውስጥ ያለው
# Tokens: ['ኧረ', 'ድምፅ', 'አያሳስብም', 'ኢንተርኔት', 'በቅናሽ', 'አመቻቹልን', 'በአለም', 'በጣም', 'ውድ', 'ኢንተርኔት', 'ሀገር', 'ውስጥ', 'ያለው']
# 2-Grams: [('ኧረ', 'ድምፅ'), ('ድምፅ', 'አያሳስብም'), ('አያሳስብም', 'ኢንተርኔት'), ('ኢንተርኔት', 'በቅናሽ'), ('በቅናሽ', 'አመቻቹልን'), ('አመቻቹልን', 'በአለም'), ('በአለም', 'በጣም'), ('በጣም', 'ውድ'), ('ውድ', 'ኢንተርኔት'), ('ኢንተርኔት', 'ሀገር'), ('ሀገር', 'ውስጥ'), ('ውስጥ', 'ያለው')]
#
#
# Comment: thank ethiotelecom expect same internet service
# Tokens: ['thank', 'ethiotelecom', 'expect', 'same', 'internet', 'service']
# 2-Grams: [('thank', 'ethiotelecom'), ('ethiotelecom', 'expect'), ('expect', 'same'), ('same', 'internet'), ('internet', 'service')]
#
#
# Comment: need unlimited data please
# Tokens: ['need', 'unlimited', 'data', 'please']
# 2-Grams: [('need', 'unlimited'), ('unlimited', 'data'), ('data', 'please')]
#
#
# Comment: ያላ ጋዳብ ብታዳርጉ በጣም አሪፍ ነበር
# Tokens: ['ያላ', 'ጋዳብ', 'ብታዳርጉ', 'በጣም', 'አሪፍ', 'ነበር']
# 2-Grams: [('ያላ', 'ጋዳብ'), ('ጋዳብ', 'ብታዳርጉ'), ('ብታዳርጉ', 'በጣም'), ('በጣም', 'አሪፍ'), ('አሪፍ', 'ነበር')]
#
#
# Comment: please balance pay portable wifi unlimited package please please
# Tokens: ['please', 'balance', 'pay', 'portable', 'wifi', 'unlimited', 'package', 'please', 'please']
# 2-Grams: [('please', 'balance'), ('balance', 'pay'), ('pay', 'portable'), ('portable', 'wifi'), ('wifi', 'unlimited'), ('unlimited', 'package'), ('package', 'please'), ('please', 'please')]
#
#
# Comment: wow great discount what fraud fmc during unlimited call what more than hr continues call
# Tokens: ['wow', 'great', 'discount', 'what', 'fraud', 'fmc', 'during', 'unlimited', 'call', 'what', 'more', 'than', 'hr', 'continues', 'call']
# 2-Grams: [('wow', 'great'), ('great', 'discount'), ('discount', 'what'), ('what', 'fraud'), ('fraud', 'fmc'), ('fmc', 'during'), ('during', 'unlimited'), ('unlimited', 'call'), ('call', 'what'), ('what', 'more'), ('more', 'than'), ('than', 'hr'), ('hr', 'continues'), ('continues', 'call')]
#
#
# Comment: waiting big discount broadband internet please apply fast possible
# Tokens: ['waiting', 'big', 'discount', 'broadband', 'internet', 'please', 'apply', 'fast', 'possible']
# 2-Grams: [('waiting', 'big'), ('big', 'discount'), ('discount', 'broadband'), ('broadband', 'internet'), ('internet', 'please'), ('please', 'apply'), ('apply', 'fast'), ('fast', 'possible')]
#
#
# Comment: nice need daily unlimited data package
# Tokens: ['nice', 'need', 'daily', 'unlimited', 'data', 'package']
# ...
# 2-Grams: [('ቴሌኮሚኒኬሽን', 'ኢትዮጵያን'), ('ኢትዮጵያን', 'በግልፅ'), ('በግልፅ', 'መዝረፍ'), ('መዝረፍ', 'ከጀመራችሁ'), ('ከጀመራችሁ', 'ቆያችሁ'), ('ቆያችሁ', 'ይቴሌብር'), ('ይቴሌብር', 'ወኪሎችን'), ('ወኪሎችን', 'ክፍያ'), ('ክፍያ', 'ክፈሉ')]
#
#
# Comment: አላስችል አለኝ ትንሽ ልተንፍሰው ደቂቃ ጠብቁኝ ግፉ ሞልቶ እየፈሰሰ አላህ ሆይ ስቃያችንን በቃበለን
# Tokens: ['አላስችል', 'አለኝ', 'ትንሽ', 'ልተንፍሰው', 'ደቂቃ', 'ጠብቁኝ', 'ግፉ', 'ሞልቶ', 'እየፈሰሰ', 'አላህ', 'ሆይ', 'ስቃያችንን', 'በቃበለን']
# 2-Grams: [('አላስችል', 'አለኝ'), ('አለኝ', 'ትንሽ'), ('ትንሽ', 'ልተንፍሰው'), ('ልተንፍሰው', 'ደቂቃ'), ('ደቂቃ', 'ጠብቁኝ'), ('ጠብቁኝ', 'ግፉ'), ('ግፉ', 'ሞልቶ'), ('ሞልቶ', 'እየፈሰሰ'), ('እየፈሰሰ', 'አላህ'), ('አላህ', 'ሆይ'), ('ሆይ', 'ስቃያችንን'), ('ስቃያችንን', 'በቃበለን')]
#
#
# Comment: አማራ ክልል አይታወቅም እዴ
# Tokens: ['አማራ', 'ክልል', 'አይታወቅም', 'እዴ']
# 2-Grams: [('አማራ', 'ክልል'), ('ክልል', 'አይታወቅም'), ('አይታወቅም', 'እዴ')]
#
#
# Comment: አሬቻ ፓኬጅ ሊኖር ይጋባል
# Tokens: ['አሬቻ', 'ፓኬጅ', 'ሊኖር', 'ይጋባል']
# 2-Grams: [('አሬቻ', 'ፓኬጅ'), ('ፓኬጅ', 'ሊኖር'), ('ሊኖር', 'ይጋባል')]
#
#
# Comment: አሬቻ ባህል የሆነው ከመቼ ጀምሮ ዛፍንና ባህርን የሚያስመልክ ጣኦት
# Tokens: ['አሬቻ', 'ባህል', 'የሆነው', 'ከመቼ', 'ጀምሮ', 'ዛፍንና', 'ባህርን', 'የሚያስመልክ', 'ጣኦት']
# 2-Grams: [('አሬቻ', 'ባህል'), ('ባህል', 'የሆነው'), ('የሆነው', 'ከመቼ'), ('ከመቼ', 'ጀምሮ'), ('ጀምሮ', 'ዛፍንና'), ('ዛፍንና', 'ባህርን'), ('ባህርን', 'የሚያስመልክ'), ('የሚያስመልክ', 'ጣኦት')]
#
#
# Comment: አርሲ ዞን አዚህ መሀል አገር ለምን ተዘለለ
# Tokens: ['አርሲ', 'ዞን', 'አዚህ', 'መሀል', 'አገር', 'ለምን', 'ተዘለለ']
# 2-Grams: [('አርሲ', 'ዞን'), ('ዞን', 'አዚህ'), ('አዚህ', 'መሀል'), ('መሀል', 'አገር'), ('አገር', 'ለምን'), ('ለምን', 'ተዘለለ')]
#
#
# Comment: አደለም አለ ኔትወርክ እንኳን ባስተካከላችሁ ለምሳሌ አዲስ ቅዳም ስልክ የዘለለ አይሰራም
# Tokens: ['አደለም', 'አለ', 'ኔትወርክ', 'እንኳን', 'ባስተካከላችሁ', 'ለምሳሌ', 'አዲስ', 'ቅዳም', 'ስልክ', 'የዘለለ', 'አይሰራም']
# 2-Grams: [('አደለም', 'አለ'), ('አለ', 'ኔትወርክ'), ('ኔትወርክ', 'እንኳን'), ('እንኳን', 'ባስተካከላችሁ'), ('ባስተካከላችሁ', 'ለምሳሌ'), ('ለምሳሌ', 'አዲስ'), ('አዲስ', 'ቅዳም'), ('ቅዳም', 'ስልክ'), ('ስልክ', 'የዘለለ'), ('የዘለለ', 'አይሰራም')]
#
#
# Comment: አደይ አበባ የወር ጥቅል ገዛሁ ፓኬጁ ሳያልቅ ደረሰ ይዘጋል ወይስ አይዘጋም
# Tokens: ['አደይ', 'አበባ', 'የወር', 'ጥቅል', 'ገዛሁ', 'ፓኬጁ', 'ሳያልቅ', 'ደረሰ', 'ይዘጋል', 'ወይስ', 'አይዘጋም']
# 2-Grams: [('አደይ', 'አበባ'), ('አበባ', 'የወር'), ('የወር', 'ጥቅል'), ('ጥቅል', 'ገዛሁ'), ('ገዛሁ', 'ፓኬጁ'), ('ፓኬጁ', 'ሳያልቅ'), ('ሳያልቅ', 'ደረሰ'), ('ደረሰ', 'ይዘጋል'), ('ይዘጋል', 'ወይስ'), ('ወይስ', 'አይዘጋም')]
#
#
# Comment: አደይ አበባ ጥቅል ብዙም ከሌሎች የተለየ ቅናሽ የለውም
# Tokens: ['አደይ', 'አበባ', 'ጥቅል', 'ብዙም', 'ከሌሎች', 'የተለየ', 'ቅናሽ', 'የለውም']
# 2-Grams: [('አደይ', 'አበባ'), ('አበባ', 'ጥቅል'), ('ጥቅል', 'ብዙም'), ('ብዙም', 'ከሌሎች'), ('ከሌሎች', 'የተለየ'), ('የተለየ', 'ቅናሽ'), ('ቅናሽ', 'የለውም')]
#
#
# Comment: አጭበርባሪ ሌባ
# Tokens: ['አጭበርባሪ', 'ሌባ']
# 2-Grams: [('አጭበርባሪ', 'ሌባ')]
#
#
# Comment: አጭቤ
# Tokens: ['አጭቤ']
# 2-Grams: []
#
#
# Comment: ኢትዮ ቴሌኮም ማጭበርበር የያዘው ቴሌ ቦነስ እሰጣለው ብሎ ለአየር የሚውለው መጀመሪያስ የአየር ያገኛሉ አይሻልም ገና ለገና ህዝቡ አያስታውልም ተብሎ ደግነቱ ብዙ የቴሌብር ተጠቃሚ የለም
# Tokens: ['ኢትዮ', 'ቴሌኮም', 'ማጭበርበር', 'የያዘው', 'ቴሌ', 'ቦነስ', 'እሰጣለው', 'ብሎ', 'ለአየር', 'የሚውለው', 'መጀመሪያስ', 'የአየር', 'ያገኛሉ', 'አይሻልም', 'ገና', 'ለገና', 'ህዝቡ', 'አያስታውልም', 'ተብሎ', 'ደግነቱ', 'ብዙ', 'የቴሌብር', 'ተጠቃሚ', 'የለም']
# 2-Grams: [('ኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'ማጭበርበር'), ('ማጭበርበር', 'የያዘው'), ('የያዘው', 'ቴሌ'), ('ቴሌ', 'ቦነስ'), ('ቦነስ', 'እሰጣለው'), ('እሰጣለው', 'ብሎ'), ('ብሎ', 'ለአየር'), ('ለአየር', 'የሚውለው'), ('የሚውለው', 'መጀመሪያስ'), ('መጀመሪያስ', 'የአየር'), ('የአየር', 'ያገኛሉ'), ('ያገኛሉ', 'አይሻልም'), ('አይሻልም', 'ገና'), ('ገና', 'ለገና'), ('ለገና', 'ህዝቡ'), ('ህዝቡ', 'አያስታውልም'), ('አያስታውልም', 'ተብሎ'), ('ተብሎ', 'ደግነቱ'), ('ደግነቱ', 'ብዙ'), ('ብዙ', 'የቴሌብር'), ('የቴሌብር', 'ተጠቃሚ'), ('ተጠቃሚ', 'የለም')]
#
#
# Comment: ኢትዮቴል ለምን ያለ ዳታ አይሰራም
# Tokens: ['ኢትዮቴል', 'ለምን', 'ያለ', 'ዳታ', 'አይሰራም']
# 2-Grams: [('ኢትዮቴል', 'ለምን'), ('ለምን', 'ያለ'), ('ያለ', 'ዳታ'), ('ዳታ', 'አይሰራም')]
#
#
# Comment: ኢትዮዎች እባካቹ ሰሙኑን በፉሪ ባቡር ጣቢያ አከባቢ ሚንም በሚባል ሁኔታ ኮኔክሽን አይሰራም አረ መላ በሉት
# Tokens: ['ኢትዮዎች', 'እባካቹ', 'ሰሙኑን', 'በፉሪ', 'ባቡር', 'ጣቢያ', 'አከባቢ', 'ሚንም', 'በሚባል', 'ሁኔታ', 'ኮኔክሽን', 'አይሰራም', 'አረ', 'መላ', 'በሉት']
# 2-Grams: [('ኢትዮዎች', 'እባካቹ'), ('እባካቹ', 'ሰሙኑን'), ('ሰሙኑን', 'በፉሪ'), ('በፉሪ', 'ባቡር'), ('ባቡር', 'ጣቢያ'), ('ጣቢያ', 'አከባቢ'), ('አከባቢ', 'ሚንም'), ('ሚንም', 'በሚባል'), ('በሚባል', 'ሁኔታ'), ('ሁኔታ', 'ኮኔክሽን'), ('ኮኔክሽን', 'አይሰራም'), ('አይሰራም', 'አረ'), ('አረ', 'መላ'), ('መላ', 'በሉት')]
#
#
# Comment: እናመሰግናለን
# Tokens: ['እናመሰግናለን']
# 2-Grams: []
#
#
# Comment: እሄ ዬ እሬቻ አይደለም የገና ይመስላል
# Tokens: ['እሄ', 'ዬ', 'እሬቻ', 'አይደለም', 'የገና', 'ይመስላል']
# 2-Grams: [('እሄ', 'ዬ'), ('ዬ', 'እሬቻ'), ('እሬቻ', 'አይደለም'), ('አይደለም', 'የገና'), ('የገና', 'ይመስላል')]
#
#
# Comment: እረረ እሱን ተውትና እረረ በፈጠራቹ ዳታ ዋይፋይ ፍጥነቱ ቀንሶብናል አስተካክሉልን ኡኡ
# Tokens: ['እረረ', 'እሱን', 'ተውትና', 'እረረ', 'በፈጠራቹ', 'ዳታ', 'ዋይፋይ', 'ፍጥነቱ', 'ቀንሶብናል', 'አስተካክሉልን', 'ኡኡ']
# 2-Grams: [('እረረ', 'እሱን'), ('እሱን', 'ተውትና'), ('ተውትና', 'እረረ'), ('እረረ', 'በፈጠራቹ'), ('በፈጠራቹ', 'ዳታ'), ('ዳታ', 'ዋይፋይ'), ('ዋይፋይ', 'ፍጥነቱ'), ('ፍጥነቱ', 'ቀንሶብናል'), ('ቀንሶብናል', 'አስተካክሉልን'), ('አስተካክሉልን', 'ኡኡ')]
#
#
# Comment: እባካችሁ በመተከል ዞን በጉባ ወረዳ የኔትወረክ መጥፋት ወረ በለጠዉመፍቴሄ ሰጡን እባካችሁ በብልፅግና የሃገራችንን ቴክሌኖጅን አጣን እባካችሁ
# Tokens: ['እባካችሁ', 'በመተከል', 'ዞን', 'በጉባ', 'ወረዳ', 'የኔትወረክ', 'መጥፋት', 'ወረ', 'በለጠዉመፍቴሄ', 'ሰጡን', 'እባካችሁ', 'በብልፅግና', 'የሃገራችንን', 'ቴክሌኖጅን', 'አጣን', 'እባካችሁ']
# 2-Grams: [('እባካችሁ', 'በመተከል'), ('በመተከል', 'ዞን'), ('ዞን', 'በጉባ'), ('በጉባ', 'ወረዳ'), ('ወረዳ', 'የኔትወረክ'), ('የኔትወረክ', 'መጥፋት'), ('መጥፋት', 'ወረ'), ('ወረ', 'በለጠዉመፍቴሄ'), ('በለጠዉመፍቴሄ', 'ሰጡን'), ('ሰጡን', 'እባካችሁ'), ('እባካችሁ', 'በብልፅግና'), ('በብልፅግና', 'የሃገራችንን'), ('የሃገራችንን', 'ቴክሌኖጅን'), ('ቴክሌኖጅን', 'አጣን'), ('አጣን', 'እባካችሁ')]
#
#
# Comment: እቺ ነገር አበሏ ደና ናት መሰለኝ
# Tokens: ['እቺ', 'ነገር', 'አበሏ', 'ደና', 'ናት', 'መሰለኝ']
# 2-Grams: [('እቺ', 'ነገር'), ('ነገር', 'አበሏ'), ('አበሏ', 'ደና'), ('ደና', 'ናት'), ('ናት', 'መሰለኝ')]
#
#
# Comment: አልገባኝም በፊት አንድም ቀን ተቋርጦብኝ የማያውቅ ኢንተርኔት አገልግሎት አስጀመርን ካላችሁ በሃላ ሊሰራልኝ አልቻለም ሌሎችንም ስጠይቅ መቆራረጥ እንዳጋጠማቸው ነግረውኛል የተሻለ አገልግሎት እንጠቀማለን ስንል እንዴት እንዲህ ሊሆን ይችላል
# Tokens: ['አልገባኝም', 'በፊት', 'አንድም', 'ቀን', 'ተቋርጦብኝ', 'የማያውቅ', 'ኢንተርኔት', 'አገልግሎት', 'አስጀመርን', 'ካላችሁ', 'በሃላ', 'ሊሰራልኝ', 'አልቻለም', 'ሌሎችንም', 'ስጠይቅ', 'መቆራረጥ', 'እንዳጋጠማቸው', 'ነግረውኛል', 'የተሻለ', 'አገልግሎት', 'እንጠቀማለን', 'ስንል', 'እንዴት', 'እንዲህ', 'ሊሆን', 'ይችላል']
# 2-Grams: [('አልገባኝም', 'በፊት'), ('በፊት', 'አንድም'), ('አንድም', 'ቀን'), ('ቀን', 'ተቋርጦብኝ'), ('ተቋርጦብኝ', 'የማያውቅ'), ('የማያውቅ', 'ኢንተርኔት'), ('ኢንተርኔት', 'አገልግሎት'), ('አገልግሎት', 'አስጀመርን'), ('አስጀመርን', 'ካላችሁ'), ('ካላችሁ', 'በሃላ'), ('በሃላ', 'ሊሰራልኝ'), ('ሊሰራልኝ', 'አልቻለም'), ('አልቻለም', 'ሌሎችንም'), ('ሌሎችንም', 'ስጠይቅ'), ('ስጠይቅ', 'መቆራረጥ'), ('መቆራረጥ', 'እንዳጋጠማቸው'), ('እንዳጋጠማቸው', 'ነግረውኛል'), ('ነግረውኛል', 'የተሻለ'), ('የተሻለ', 'አገልግሎት'), ('አገልግሎት', 'እንጠቀማለን'), ('እንጠቀማለን', 'ስንል'), ('ስንል', 'እንዴት'), ('እንዴት', 'እንዲህ'), ('እንዲህ', 'ሊሆን'), ('ሊሆን', 'ይችላል')]
#
#
# Comment: እንኳን አብሮ አደረሰን ኢትዮ ቴሌኮም መሻሻል እያደረጋችሁ በርቱ
# Tokens: ['እንኳን', 'አብሮ', 'አደረሰን', 'ኢትዮ', 'ቴሌኮም', 'መሻሻል', 'እያደረጋችሁ', 'በርቱ']
# 2-Grams: [('እንኳን', 'አብሮ'), ('አብሮ', 'አደረሰን'), ('አደረሰን', 'ኢትዮ'), ('ኢትዮ', 'ቴሌኮም'), ('ቴሌኮም', 'መሻሻል'), ('መሻሻል', 'እያደረጋችሁ'), ('እያደረጋችሁ', 'በርቱ')]
#
#
# Comment: እንኳን አብሮን አደረሰን
# Tokens: ['እንኳን', 'አብሮን', 'አደረሰን']
# 2-Grams: [('እንኳን', 'አብሮን'), ('አብሮን', 'አደረሰን')]
#
#
# Comment: እንዴት እንጠቀማለን ስጦታውን የኢንቴርኔት አገልግሎት ከተቋረጠ ወራቶች አልፎታል እየተጠቀምን ያለነው በዋይፋይ እባካቹ ደቡብ ክልል ቡርጂ ልዩ ወረዳ ህብረተሰቡ የኢንተርኔት ተጠቀምን የምሆንበት መፍትሄ ብትወስዱ ቡርጂ ልዩ ወረዳ ውስጥ ኢንቴርኔት አገልግሎት ከተቋረጠ ወራቶች ተቆጥሯል እባካቹ መፍትሄ ብወሰድ
# Tokens: ['እንዴት', 'እንጠቀማለን', 'ስጦታውን', 'የኢንቴርኔት', 'አገልግሎት', 'ከተቋረጠ', 'ወራቶች', 'አልፎታል', 'እየተጠቀምን', 'ያለነው', 'በዋይፋይ', 'እባካቹ', 'ደቡብ', 'ክልል', 'ቡርጂ', 'ልዩ', 'ወረዳ', 'ህብረተሰቡ', 'የኢንተርኔት', 'ተጠቀምን', 'የምሆንበት', 'መፍትሄ', 'ብትወስዱ', 'ቡርጂ', 'ልዩ', 'ወረዳ', 'ውስጥ', 'ኢንቴርኔት', 'አገልግሎት', 'ከተቋረጠ', 'ወራቶች', 'ተቆጥሯል', 'እባካቹ', 'መፍትሄ', 'ብወሰድ']
# 2-Grams: [('እንዴት', 'እንጠቀማለን'), ('እንጠቀማለን', 'ስጦታውን'), ('ስጦታውን', 'የኢንቴርኔት'), ('የኢንቴርኔት', 'አገልግሎት'), ('አገልግሎት', 'ከተቋረጠ'), ('ከተቋረጠ', 'ወራቶች'), ('ወራቶች', 'አልፎታል'), ('አልፎታል', 'እየተጠቀምን'), ('እየተጠቀምን', 'ያለነው'), ('ያለነው', 'በዋይፋይ'), ('በዋይፋይ', 'እባካቹ'), ('እባካቹ', 'ደቡብ'), ('ደቡብ', 'ክልል'), ('ክልል', 'ቡርጂ'), ('ቡርጂ', 'ልዩ'), ('ልዩ', 'ወረዳ'), ('ወረዳ', 'ህብረተሰቡ'), ('ህብረተሰቡ', 'የኢንተርኔት'), ('የኢንተርኔት', 'ተጠቀምን'), ('ተጠቀምን', 'የምሆንበት'), ('የምሆንበት', 'መፍትሄ'), ('መፍትሄ', 'ብትወስዱ'), ('ብትወስዱ', 'ቡርጂ'), ('ቡርጂ', 'ልዩ'), ('ልዩ', 'ወረዳ'), ('ወረዳ', 'ውስጥ'), ('ውስጥ', 'ኢንቴርኔት'), ('ኢንቴርኔት', 'አገልግሎት'), ('አገልግሎት', 'ከተቋረጠ'), ('ከተቋረጠ', 'ወራቶች'), ('ወራቶች', 'ተቆጥሯል'), ('ተቆጥሯል', 'እባካቹ'), ('እባካቹ', 'መፍትሄ'), ('መፍትሄ', 'ብወሰድ')]
#
#
# Comment: እንዴት ናቹቅሬታ ላቀርብ ተገድጃለው በክፍያ ምክኒያት የቤቴ wifi ተቋርጦ እኔም ውዬ ሳላድር ክፍያውን ብከፍልም ይህው እስካሁን መስመሩ ሊለቀቅልኝ አልቻለው ክፍያውን ከከፈልኩ ድፍን ሆኖኛል በተደጋጋሚ ብደውልም ይለቀቃል ትንሽ ይጠብቁ ብለው የመከታተያ ቁጥር ልከው እስካሁን የለም በብልሽት ምክኒያት ያልተቋረጠን መስመር እንዴት እንዲህ ይቆያል የተቋረጠው በብር ምክኒያት እንደመሆኑ ለምን ክፍያ እንደፈፀምኩ አልተለቀቀም የፈለገ ክፍያ ባልከፍል ለምን ይቋረጣል መስመሩ
# Tokens: ['እንዴት', 'ናቹቅሬታ', 'ላቀርብ', 'ተገድጃለው', 'በክፍያ', 'ምክኒያት', 'የቤቴ', 'wifi', 'ተቋርጦ', 'እኔም', 'ውዬ', 'ሳላድር', 'ክፍያውን', 'ብከፍልም', 'ይህው', 'እስካሁን', 'መስመሩ', 'ሊለቀቅልኝ', 'አልቻለው', 'ክፍያውን', 'ከከፈልኩ', 'ድፍን', 'ሆኖኛል', 'በተደጋጋሚ', 'ብደውልም', 'ይለቀቃል', 'ትንሽ', 'ይጠብቁ', 'ብለው', 'የመከታተያ', 'ቁጥር', 'ልከው', 'እስካሁን', 'የለም', 'በብልሽት', 'ምክኒያት', 'ያልተቋረጠን', 'መስመር', 'እንዴት', 'እንዲህ', 'ይቆያል', 'የተቋረጠው', 'በብር', 'ምክኒያት', 'እንደመሆኑ', 'ለምን', 'ክፍያ', 'እንደፈፀምኩ', 'አልተለቀቀም', 'የፈለገ', 'ክፍያ', 'ባልከፍል', 'ለምን', 'ይቋረጣል', 'መስመሩ']
# 2-Grams: [('እንዴት', 'ናቹቅሬታ'), ('ናቹቅሬታ', 'ላቀርብ'), ('ላቀርብ', 'ተገድጃለው'), ('ተገድጃለው', 'በክፍያ'), ('በክፍያ', 'ምክኒያት'), ('ምክኒያት', 'የቤቴ'), ('የቤቴ', 'wifi'), ('wifi', 'ተቋርጦ'), ('ተቋርጦ', 'እኔም'), ('እኔም', 'ውዬ'), ('ውዬ', 'ሳላድር'), ('ሳላድር', 'ክፍያውን'), ('ክፍያውን', 'ብከፍልም'), ('ብከፍልም', 'ይህው'), ('ይህው', 'እስካሁን'), ('እስካሁን', 'መስመሩ'), ('መስመሩ', 'ሊለቀቅልኝ'), ('ሊለቀቅልኝ', 'አልቻለው'), ('አልቻለው', 'ክፍያውን'), ('ክፍያውን', 'ከከፈልኩ'), ('ከከፈልኩ', 'ድፍን'), ('ድፍን', 'ሆኖኛል'), ('ሆኖኛል', 'በተደጋጋሚ'), ('በተደጋጋሚ', 'ብደውልም'), ('ብደውልም', 'ይለቀቃል'), ('ይለቀቃል', 'ትንሽ'), ('ትንሽ', 'ይጠብቁ'), ('ይጠብቁ', 'ብለው'), ('ብለው', 'የመከታተያ'), ('የመከታተያ', 'ቁጥር'), ('ቁጥር', 'ልከው'), ('ልከው', 'እስካሁን'), ('እስካሁን', 'የለም'), ('የለም', 'በብልሽት'), ('በብልሽት', 'ምክኒያት'), ('ምክኒያት', 'ያልተቋረጠን'), ('ያልተቋረጠን', 'መስመር'), ('መስመር', 'እንዴት'), ('እንዴት', 'እንዲህ'), ('እንዲህ', 'ይቆያል'), ('ይቆያል', 'የተቋረጠው'), ('የተቋረጠው', 'በብር'), ('በብር', 'ምክኒያት'), ('ምክኒያት', 'እንደመሆኑ'), ('እንደመሆኑ', 'ለምን'), ('ለምን', 'ክፍያ'), ('ክፍያ', 'እንደፈፀምኩ'), ('እንደፈፀምኩ', 'አልተለቀቀም'), ('አልተለቀቀም', 'የፈለገ'), ('የፈለገ', 'ክፍያ'), ('ክፍያ', 'ባልከፍል'), ('ባልከፍል', 'ለምን'), ('ለምን', 'ይቋረጣል'), ('ይቋረጣል', 'መስመሩ')]
#
#
# Comment: ለማስቀየር ወደማእከል መሄድ ለምን አስፈለገ ለምን ራሳችሁ አታስተካክሉትም የሽያጭ ማእከሎቻችሁ እኮ እንኳን ይህን ለማስተናገድ ሲም ለመግዛት የሰኣታት ወረፈ መጠበቅ ግድ
# Tokens: ['ለማስቀየር', 'ወደማእከል', 'መሄድ', 'ለምን', 'አስፈለገ', 'ለምን', 'ራሳችሁ', 'አታስተካክሉትም', 'የሽያጭ', 'ማእከሎቻችሁ', 'እኮ', 'እንኳን', 'ይህን', 'ለማስተናገድ', 'ሲም', 'ለመግዛት', 'የሰኣታት', 'ወረፈ', 'መጠበቅ', 'ግድ']
# 2-Grams: [('ለማስቀየር', 'ወደማእከል'), ('ወደማእከል', 'መሄድ'), ('መሄድ', 'ለምን'), ('ለምን', 'አስፈለገ'), ('አስፈለገ', 'ለምን'), ('ለምን', 'ራሳችሁ'), ('ራሳችሁ', 'አታስተካክሉትም'), ('አታስተካክሉትም', 'የሽያጭ'), ('የሽያጭ', 'ማእከሎቻችሁ'), ('ማእከሎቻችሁ', 'እኮ'), ('እኮ', 'እንኳን'), ('እንኳን', 'ይህን'), ('ይህን', 'ለማስተናገድ'), ('ለማስተናገድ', 'ሲም'), ('ሲም', 'ለመግዛት'), ('ለመግዛት', 'የሰኣታት'), ('የሰኣታት', 'ወረፈ'), ('ወረፈ', 'መጠበቅ'), ('መጠበቅ', 'ግድ')]
#
#
# Comment: ወሬብቸ እጅ ኔቶርክ የለምበፍት የምሰረ ረሱ የለም
# Tokens: ['ወሬብቸ', 'እጅ', 'ኔቶርክ', 'የለምበፍት', 'የምሰረ', 'ረሱ', 'የለም']
# 2-Grams: [('ወሬብቸ', 'እጅ'), ('እጅ', 'ኔቶርክ'), ('ኔቶርክ', 'የለምበፍት'), ('የለምበፍት', 'የምሰረ'), ('የምሰረ', 'ረሱ'), ('ረሱ', 'የለም')]
#
#
# Comment: ወዴ ቴሌ ሳንሄድ ካርዳችንን የምናሳድግበትን መንገድ ቢመቻች ጥሩ ይመስለኛል ምክንያቱም አብዛኛው የገጠር ሰራተኞችን ቴሌን ለማግኘት የግድ ከተማ መሄድ ሊጠበቅባቸው ስለሚሆን
# Tokens: ['ወዴ', 'ቴሌ', 'ሳንሄድ', 'ካርዳችንን', 'የምናሳድግበትን', 'መንገድ', 'ቢመቻች', 'ጥሩ', 'ይመስለኛል', 'ምክንያቱም', 'አብዛኛው', 'የገጠር', 'ሰራተኞችን', 'ቴሌን', 'ለማግኘት', 'የግድ', 'ከተማ', 'መሄድ', 'ሊጠበቅባቸው', 'ስለሚሆን']
# 2-Grams: [('ወዴ', 'ቴሌ'), ('ቴሌ', 'ሳንሄድ'), ('ሳንሄድ', 'ካርዳችንን'), ('ካርዳችንን', 'የምናሳድግበትን'), ('የምናሳድግበትን', 'መንገድ'), ('መንገድ', 'ቢመቻች'), ('ቢመቻች', 'ጥሩ'), ('ጥሩ', 'ይመስለኛል'), ('ይመስለኛል', 'ምክንያቱም'), ('ምክንያቱም', 'አብዛኛው'), ('አብዛኛው', 'የገጠር'), ('የገጠር', 'ሰራተኞችን'), ('ሰራተኞችን', 'ቴሌን'), ('ቴሌን', 'ለማግኘት'), ('ለማግኘት', 'የግድ'), ('የግድ', 'ከተማ'), ('ከተማ', 'መሄድ'), ('መሄድ', 'ሊጠበቅባቸው'), ('ሊጠበቅባቸው', 'ስለሚሆን')]
#
#
# Comment: ውሺታሞች አታፍሩም ደሞ ቅናሺ ትላላቸ የባሰ የምትቆርጡ አናቅም
# Tokens: ['ውሺታሞች', 'አታፍሩም', 'ደሞ', 'ቅናሺ', 'ትላላቸ', 'የባሰ', 'የምትቆርጡ', 'አናቅም']
# 2-Grams: [('ውሺታሞች', 'አታፍሩም'), ('አታፍሩም', 'ደሞ'), ('ደሞ', 'ቅናሺ'), ('ቅናሺ', 'ትላላቸ'), ('ትላላቸ', 'የባሰ'), ('የባሰ', 'የምትቆርጡ'), ('የምትቆርጡ', 'አናቅም')]
#
#
# Comment: pin ቁጥሩን እረሳሁት ምን ላድርግ
# Tokens: ['pin', 'ቁጥሩን', 'እረሳሁት', 'ምን', 'ላድርግ']
# 2-Grams: [('pin', 'ቁጥሩን'), ('ቁጥሩን', 'እረሳሁት'), ('እረሳሁት', 'ምን'), ('ምን', 'ላድርግ')]
#
#
# Comment: የታላቁ የህዳሴ ግድብ ጉባ ኔትወርክ ከተበላሸ አመት አልፎታል ኔትወርክ በሌለበት ቦታ ማለት ቀልድ
# Tokens: ['የታላቁ', 'የህዳሴ', 'ግድብ', 'ጉባ', 'ኔትወርክ', 'ከተበላሸ', 'አመት', 'አልፎታል', 'ኔትወርክ', 'በሌለበት', 'ቦታ', 'ማለት', 'ቀልድ']
# 2-Grams: [('የታላቁ', 'የህዳሴ'), ('የህዳሴ', 'ግድብ'), ('ግድብ', 'ጉባ'), ('ጉባ', 'ኔትወርክ'), ('ኔትወርክ', 'ከተበላሸ'), ('ከተበላሸ', 'አመት'), ('አመት', 'አልፎታል'), ('አልፎታል', 'ኔትወርክ'), ('ኔትወርክ', 'በሌለበት'), ('በሌለበት', 'ቦታ'), ('ቦታ', 'ማለት'), ('ማለት', 'ቀልድ')]
#
#
# Comment: የቴሌብር አፕሊኬሽን ከፕላይስቶር አውርጀ ብጠቀምም ስልኬን ስካን ሳደርግ በቫይረስ ተጠቅቷል እያለኝ ስለሆነ መፍትሄ ካላችሁ ብትሰጡኝ
# Tokens: ['የቴሌብር', 'አፕሊኬሽን', 'ከፕላይስቶር', 'አውርጀ', 'ብጠቀምም', 'ስልኬን', 'ስካን', 'ሳደርግ', 'በቫይረስ', 'ተጠቅቷል', 'እያለኝ', 'ስለሆነ', 'መፍትሄ', 'ካላችሁ', 'ብትሰጡኝ']
# 2-Grams: [('የቴሌብር', 'አፕሊኬሽን'), ('አፕሊኬሽን', 'ከፕላይስቶር'), ('ከፕላይስቶር', 'አውርጀ'), ('አውርጀ', 'ብጠቀምም'), ('ብጠቀምም', 'ስልኬን'), ('ስልኬን', 'ስካን'), ('ስካን', 'ሳደርግ'), ('ሳደርግ', 'በቫይረስ'), ('በቫይረስ', 'ተጠቅቷል'), ('ተጠቅቷል', 'እያለኝ'), ('እያለኝ', 'ስለሆነ'), ('ስለሆነ', 'መፍትሄ'), ('መፍትሄ', 'ካላችሁ'), ('ካላችሁ', 'ብትሰጡኝ')]
#
#
# Comment: የኢሬቻ በኣል ልዩ የጥቅል አገልግሎት ለምን አይስጥም በአልን እኩል ተመልከቱ እንጂ ማዳላት ጥሩ አይደለም
# Tokens: ['የኢሬቻ', 'በኣል', 'ልዩ', 'የጥቅል', 'አገልግሎት', 'ለምን', 'አይስጥም', 'በአልን', 'እኩል', 'ተመልከቱ', 'እንጂ', 'ማዳላት', 'ጥሩ', 'አይደለም']
# 2-Grams: [('የኢሬቻ', 'በኣል'), ('በኣል', 'ልዩ'), ('ልዩ', 'የጥቅል'), ('የጥቅል', 'አገልግሎት'), ('አገልግሎት', 'ለምን'), ('ለምን', 'አይስጥም'), ('አይስጥም', 'በአልን'), ('በአልን', 'እኩል'), ('እኩል', 'ተመልከቱ'), ('ተመልከቱ', 'እንጂ'), ('እንጂ', 'ማዳላት'), ('ማዳላት', 'ጥሩ'), ('ጥሩ', 'አይደለም')]
#
#
# Comment: የኢሬቻ ፓኬጅ ለምን አይኖርም
# Tokens: ['የኢሬቻ', 'ፓኬጅ', 'ለምን', 'አይኖርም']
# 2-Grams: [('የኢሬቻ', 'ፓኬጅ'), ('ፓኬጅ', 'ለምን'), ('ለምን', 'አይኖርም')]
#
#
# Comment: የእሬቻን በኣል በፎቶ ፓኬጅ የለም
# Tokens: ['የእሬቻን', 'በኣል', 'በፎቶ', 'ፓኬጅ', 'የለም']
# 2-Grams: [('የእሬቻን', 'በኣል'), ('በኣል', 'በፎቶ'), ('በፎቶ', 'ፓኬጅ'), ('ፓኬጅ', 'የለም')]
#
#
# Comment: የእውነት አጭበርባሪ ውሸታም
# Tokens: ['የእውነት', 'አጭበርባሪ', 'ውሸታም']
# 2-Grams: [('የእውነት', 'አጭበርባሪ'), ('አጭበርባሪ', 'ውሸታም')]
#
#
# Comment: ያለ ጥቅል አታውቁም ወይም የጊዜ ገደብ አይኑረው አታጨናንቁና ከሰጣችሁ አይቀር ፍላጎታችንን ጠብቁ
# Tokens: ['ያለ', 'ጥቅል', 'አታውቁም', 'ወይም', 'የጊዜ', 'ገደብ', 'አይኑረው', 'አታጨናንቁና', 'ከሰጣችሁ', 'አይቀር', 'ፍላጎታችንን', 'ጠብቁ']
# 2-Grams: [('ያለ', 'ጥቅል'), ('ጥቅል', 'አታውቁም'), ('አታውቁም', 'ወይም'), ('ወይም', 'የጊዜ'), ('የጊዜ', 'ገደብ'), ('ገደብ', 'አይኑረው'), ('አይኑረው', 'አታጨናንቁና'), ('አታጨናንቁና', 'ከሰጣችሁ'), ('ከሰጣችሁ', 'አይቀር'), ('አይቀር', 'ፍላጎታችንን'), ('ፍላጎታችንን', 'ጠብቁ')]
#
#
# Comment: ደብረ ብርሃን ሲጀመር ጫጫ ከተማን ለምን ዘለላችሁት
# Tokens: ['ደብረ', 'ብርሃን', 'ሲጀመር', 'ጫጫ', 'ከተማን', 'ለምን', 'ዘለላችሁት']
# 2-Grams: [('ደብረ', 'ብርሃን'), ('ብርሃን', 'ሲጀመር'), ('ሲጀመር', 'ጫጫ'), ('ጫጫ', 'ከተማን'), ('ከተማን', 'ለምን'), ('ለምን', 'ዘለላችሁት')]
#
#
# Comment: በአንድ ክልል ቦታዎች ለይ ጠረፍ በብዛት ይሰራል ሀዲያ ከምባታ ጠምባሮ ወላይታ በከፈል የኔትዎርክ ችግር በጣም አለ
# Tokens: ['በአንድ', 'ክልል', 'ቦታዎች', 'ለይ', 'ጠረፍ', 'በብዛት', 'ይሰራል', 'ሀዲያ', 'ከምባታ', 'ጠምባሮ', 'ወላይታ', 'በከፈል', 'የኔትዎርክ', 'ችግር', 'በጣም', 'አለ']
# 2-Grams: [('በአንድ', 'ክልል'), ('ክልል', 'ቦታዎች'), ('ቦታዎች', 'ለይ'), ('ለይ', 'ጠረፍ'), ('ጠረፍ', 'በብዛት'), ('በብዛት', 'ይሰራል'), ('ይሰራል', 'ሀዲያ'), ('ሀዲያ', 'ከምባታ'), ('ከምባታ', 'ጠምባሮ'), ('ጠምባሮ', 'ወላይታ'), ('ወላይታ', 'በከፈል'), ('በከፈል', 'የኔትዎርክ'), ('የኔትዎርክ', 'ችግር'), ('ችግር', 'በጣም'), ('በጣም', 'አለ')]
#
#
# Comment: መቼ የምትጀምሩት
# Tokens: ['መቼ', 'የምትጀምሩት']
# 2-Grams: [('መቼ', 'የምትጀምሩት')]
#
#
# Comment: ጭራሽ በዶላር ጨዋታ ጀመራቹ
# Tokens: ['ጭራሽ', 'በዶላር', 'ጨዋታ', 'ጀመራቹ']
# 2-Grams: [('ጭራሽ', 'በዶላር'), ('በዶላር', 'ጨዋታ'), ('ጨዋታ', 'ጀመራቹ')]
#
#
# Comment: ፍሌክሲ ለምን ተቋረጠ ሁሉንም አገልግሎቶች ለመጠቀም ስለሚረዳ ቢቀጥል
# Tokens: ['ፍሌክሲ', 'ለምን', 'ተቋረጠ', 'ሁሉንም', 'አገልግሎቶች', 'ለመጠቀም', 'ስለሚረዳ', 'ቢቀጥል']
# 2-Grams: [('ፍሌክሲ', 'ለምን'), ('ለምን', 'ተቋረጠ'), ('ተቋረጠ', 'ሁሉንም'), ('ሁሉንም', 'አገልግሎቶች'), ('አገልግሎቶች', 'ለመጠቀም'), ('ለመጠቀም', 'ስለሚረዳ'), ('ስለሚረዳ', 'ቢቀጥል')]
#
#
# Comment: ፍሬ አበበች ዘንድሮ አልተቻሉም
# Tokens: ['ፍሬ', 'አበበች', 'ዘንድሮ', 'አልተቻሉም']
# 2-Grams: [('ፍሬ', 'አበበች'), ('አበበች', 'ዘንድሮ'), ('ዘንድሮ', 'አልተቻሉም')]
#
#
# Comment: ፍሬ ጩባዉ
# Tokens: ['ፍሬ', 'ጩባዉ']
# 2-Grams: [('ፍሬ', 'ጩባዉ')]
#
#
# Comment: ፍትህ ፍትህ ፍትህ ፍትህ ለሳኡዲ እሰርኞች
# Tokens: ['ፍትህ', 'ፍትህ', 'ፍትህ', 'ፍትህ', 'ለሳኡዲ', 'እሰርኞች']
# 2-Grams: [('ፍትህ', 'ፍትህ'), ('ፍትህ', 'ፍትህ'), ('ፍትህ', 'ፍትህ'), ('ፍትህ', 'ለሳኡዲ'), ('ለሳኡዲ', 'እሰርኞች')]
#
#
# Comment: ፍትህ ፍትህ ለሳኡዱ ሰተደተኞች ፍትህ ለውሎ ህዝቦች
# Tokens: ['ፍትህ', 'ፍትህ', 'ለሳኡዱ', 'ሰተደተኞች', 'ፍትህ', 'ለውሎ', 'ህዝቦች']
# 2-Grams: [('ፍትህ', 'ፍትህ'), ('ፍትህ', 'ለሳኡዱ'), ('ለሳኡዱ', 'ሰተደተኞች'), ('ሰተደተኞች', 'ፍትህ'), ('ፍትህ', 'ለውሎ'), ('ለውሎ', 'ህዝቦች')]
#
#
# Comment: ፓከጁን ገዝተን ለምሳሌ የገዛነው ፓከጅ ተጠቅመን እያሌ ሳያልቅ ቀኑ ከደረሰ ካለፈ የቀረው እንዴት ይሆናል
# Tokens: ['ፓከጁን', 'ገዝተን', 'ለምሳሌ', 'የገዛነው', 'ፓከጅ', 'ተጠቅመን', 'እያሌ', 'ሳያልቅ', 'ቀኑ', 'ከደረሰ', 'ካለፈ', 'የቀረው', 'እንዴት', 'ይሆናል']
# 2-Grams: [('ፓከጁን', 'ገዝተን'), ('ገዝተን', 'ለምሳሌ'), ('ለምሳሌ', 'የገዛነው'), ('የገዛነው', 'ፓከጅ'), ('ፓከጅ', 'ተጠቅመን'), ('ተጠቅመን', 'እያሌ'), ('እያሌ', 'ሳያልቅ'), ('ሳያልቅ', 'ቀኑ'), ('ቀኑ', 'ከደረሰ'), ('ከደረሰ', 'ካለፈ'), ('ካለፈ', 'የቀረው'), ('የቀረው', 'እንዴት'), ('እንዴት', 'ይሆናል')]
#
#
# Comment: ፓኬጁስ
# Tokens: ['ፓኬጁስ']
# 2-Grams: []
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
